# %% [markdown]
# # Content-based recommenders
#
# Content-based recommenders in their recommendations rely purely on the features of items. Conceptually it can be expressed as a model of the form (personalized):
# <center>
# $$
#     score \sim (user, item\_feature_1, item\_feature_2, ..., item\_feature_n)
# $$
# </center>
# or (not personalized)
# <center>
# $$
#     score \sim (item\_feature_1, item\_feature_2, ..., item\_feature_n)
# $$
# </center>
#
#     + Content-based recommenders do not suffer from the cold-start problem for new items.
#     - They do not use information about complex patterns of user-item interactions - what other similar users have already discovered and liked.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Markdown, display, HTML
from collections import defaultdict
from sklearn.model_selection import KFold

# Fix the dying kernel problem (only a problem in some installations - you can remove it, if it works without it)
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %% [markdown]
# # Load the data

# %%
ml_ratings_df = pd.read_csv(os.path.join("data", "movielens_small", "ratings.csv")).rename(columns={'userId': 'user_id', 'movieId': 'item_id'})
ml_movies_df = pd.read_csv(os.path.join("data", "movielens_small", "movies.csv")).rename(columns={'movieId': 'item_id'})
ml_df = pd.merge(ml_ratings_df, ml_movies_df, on='item_id')
ml_df.head(10)

display(HTML(ml_movies_df.head(10).to_html()))

# Filter the data to reduce the number of movies
rng = np.random.RandomState(seed=6789)
left_ids = rng.choice(ml_movies_df['item_id'], size=1000, replace=False)

ml_ratings_df = ml_ratings_df.loc[ml_ratings_df['item_id'].isin(left_ids)]
ml_movies_df = ml_movies_df.loc[ml_movies_df['item_id'].isin(left_ids)]
ml_df = ml_df.loc[ml_df['item_id'].isin(left_ids)]

print("Number of left interactions: {}".format(len(ml_ratings_df)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item_id</th>
#       <th>title</th>
#       <th>genres</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Toy Story (1995)</td>
#       <td>Adventure|Animation|Children|Comedy|Fantasy</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Jumanji (1995)</td>
#       <td>Adventure|Children|Fantasy</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Grumpier Old Men (1995)</td>
#       <td>Comedy|Romance</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Waiting to Exhale (1995)</td>
#       <td>Comedy|Drama|Romance</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Father of the Bride Part II (1995)</td>
#       <td>Comedy</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>Heat (1995)</td>
#       <td>Action|Crime|Thriller</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>Sabrina (1995)</td>
#       <td>Comedy|Romance</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>Tom and Huck (1995)</td>
#       <td>Adventure|Children</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>Sudden Death (1995)</td>
#       <td>Action</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>GoldenEye (1995)</td>
#       <td>Action|Adventure|Thriller</td>
#     </tr>
#   </tbody>
# </table>
# Number of left interactions: 9692

# %% [markdown]
# # Recommender class
#
# Remark: Docstrings written in reStructuredText (reST) used by Sphinx to automatically generate code documentation. It is also used by default by PyCharm (type triple quotes after defining a class or a method and hit enter).

# %%
class Recommender(object):
    """
    Base recommender class.
    """
    
    def __init__(self):
        """
        Initialize base recommender params and variables.
        """
        pass
    
    def fit(self, interactions_df, users_df, items_df):
        """
        Training of the recommender.
        
        :param pd.DataFrame interactions_df: DataFrame with recorded interactions between users and items 
            defined by user_id, item_id and features of the interaction.
        :param pd.DataFrame users_df: DataFrame with users and their features defined by user_id and the user feature columns.
        :param pd.DataFrame items_df: DataFrame with items and their features defined by item_id and the item feature columns.
        """
        pass
    
    def recommend(self, users_df, items_df, n_recommendations=1):
        """
        Serving of recommendations. Scores items in items_df for each user in users_df and returns 
        top n_recommendations for each user.
        
        :param pd.DataFrame users_df: DataFrame with users and their features for which recommendations should be generated.
        :param pd.DataFrame items_df: DataFrame with items and their features which should be scored.
        :param int n_recommendations: Number of recommendations to be returned for each user.
        :return: DataFrame with user_id, item_id and score as columns returning n_recommendations top recommendations 
            for each user.
        :rtype: pd.DataFrame
        """
        
        recommendations = pd.DataFrame(columns=['user_id', 'item_id', 'score'])
        
        for ix, user in users_df.iterrows():
            user_recommendations = pd.DataFrame({'user_id': user['user_id'],
                                                 'item_id': [-1] * n_recommendations,
                                                 'score': [3.0] * n_recommendations})

            recommendations = pd.concat([recommendations, user_recommendations])

        return recommendations

# %% [markdown]
# # Evaluation measures

# %% [markdown]
# ## Explicit feedback - ratings

# %% [markdown]
# ### RMSE - Root Mean Squared Error
#
# <center>
# $$
#     RMSE = \sqrt{\frac{\sum_{i}^N (\hat{r}_i - r_i)^2}{N}}
# $$
# </center>
#
# where $\hat{r}_i$ are the predicted ratings and $r_i$ are the real ratings and $N$ is the number of items in the test set.
#
#     + Very well-behaved analytically and therefore extensively used to train models, especially neural networks.
#     - The scale of errors dependent on data which reduced comparability between different datasets.

# %%
def rmse(r_pred, r_real):
    return np.sqrt(np.sum(np.power(r_pred - r_real, 2)) / len(r_pred))

# Test

print("RMSE = {:.2f}".format(rmse(np.array([2.1, 1.2, 3.8, 4.2, 3.6]), np.array([3, 2, 4, 5, 1]))))
# Out:
# RMSE = 1.33

# %% [markdown]
# ### MRE - Mean Relative Error
#
# <center>
# $$
#     MRE = \frac{1}{N} \sum_{i}^N \frac{|\hat{r}_i - r_i|}{|r_i|}
# $$
# </center>
#
# where $\hat{r}_i$ are the predicted ratings and $r_i$ are the real ratings and $N$ is the number of items in the test set.
#
#     + Easily interpretable (average percentage error) and with a meaning understandable for business.
#     - Blows up when there are values close to zero among the predicted values.

# %%
def mre(r_pred, r_real):
    return 1 / len(r_pred) * np.sum(np.abs(r_pred - r_real) / np.abs(r_real))

# Test

print("MRE = {:.4f}".format(mre(np.array([2.1, 1.2, 3.8, 4.2, 3.6]), np.array([3, 2, 4, 5, 1]))))
# Out:
# MRE = 0.7020

# %% [markdown]
# ### TRE - Total Relative Error
#
# <center>
# $$
#     TRE = \frac{\sum_{i}^N |\hat{r}_i - r_i|}{\sum_{i}^N |r_i|}
# $$
# </center>
#
# where $\hat{r}_i$ are the predicted ratings and $r_i$ are the real ratings and $N$ is the number of items in the test set.
#
#     + Easily interpretable (total percentage error) and with a meaning understandable for business.
#     + Reliable even for very small predicted values.
#     - Does not distinguish between a case when one prediction is very bad and other are very good and a case when all predictions are mediocre.

# %%
def tre(r_pred, r_real):
    return np.sum(np.abs(r_pred - r_real)) / np.sum(np.abs(r_real))

# Test

print("TRE = {:.4f}".format(tre(np.array([2.1, 1.2, 3.8, 4.2, 3.6]), np.array([3, 2, 4, 5, 1]))))
# Out:
# TRE = 0.3533

# %% [markdown]
# ## Implicit feedback - binary indicators of interactions

# %% [markdown]
# ### HR@n - Hit Ratio
# How many hits did we score in the first n recommendations.
# <br/>
# <br/>
# <center>
# $$
#     \text{HR@}n = \frac{\sum_{u} \sum_{i \in I_u} r_{u, i} \cdot 1_{\hat{D}_n(u)}(i)}{M}
# $$
# </center>
#
# where:
#   * $r_{u, i}$ is $1$ if there was an interaction between user $u$ and item $i$ in the test set and $0$ otherwise,
#   * $\hat{D}_n$ is the set of the first $n$ recommendations for user $u$,
#   * $1_{\hat{D}_n}(i)$ is $1$ if and only if $i \in \hat{D}_n$, otherwise it's equal to $0$,
#   * $M$ is the number of users.
#
#
#     + Easily interpretable.
#     - Does not take the rank of each recommendation into account.

# %%
def hr(recommendations, real_interactions, n=1):
    """
    Assumes recommendations are ordered by user_id and then by score.
    """
    # Transform real_interactions to a dict for a large speed-up
    rui = defaultdict(lambda: 0)
    
    for idx, row in real_interactions.iterrows():
        rui[(row['user_id'], row['item_id'])] = 1
        
    hr = 0.0
    
    previous_user_id = -1
    rank = 0
    for idx, row in recommendations.iterrows():
        if previous_user_id == row['user_id']:
            rank += 1
        else:
            rank = 1
            
        if rank <= n:
            hr += rui[(row['user_id'], row['item_id'])]
        
        previous_user_id = row['user_id']
    
    hr /= len(recommendations['user_id'].unique())
    
    return hr

    
recommendations = pd.DataFrame(
    [
        [1, 13, 0.9],
        [1, 45, 0.8],
        [1, 22, 0.71],
        [1, 77, 0.55],
        [1, 9, 0.52],
        [2, 11, 0.85],
        [2, 13, 0.69],
        [2, 25, 0.64],
        [2, 6, 0.60],
        [2, 77, 0.53]
        
    ], columns=['user_id', 'item_id', 'score'])

display(HTML(recommendations.to_html()))

real_interactions = pd.DataFrame(
    [
        [1, 45],
        [1, 22],
        [1, 77],
        [2, 13],
        [2, 77]
        
    ], columns=['user_id', 'item_id'])

display(HTML(real_interactions.to_html()))
    
print("HR@3 = {:.4f}".format(hr(recommendations, real_interactions, n=3)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>item_id</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>13</td>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>45</td>
#       <td>0.80</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>22</td>
#       <td>0.71</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>77</td>
#       <td>0.55</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>9</td>
#       <td>0.52</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>11</td>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2</td>
#       <td>13</td>
#       <td>0.69</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2</td>
#       <td>25</td>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2</td>
#       <td>6</td>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2</td>
#       <td>77</td>
#       <td>0.53</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>item_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>77</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>77</td>
#     </tr>
#   </tbody>
# </table>
# HR@3 = 1.5000

# %% [markdown]
# ### NDCG@n - Normalized Discounted Cumulative Gain
#
# How many hits did we score in the first n recommendations discounted by the position of each recommendation.
# <br/>
# <br/>
# <center>
# $$
#     \text{NDCG@}n = \frac{\sum_{u} \sum_{i \in I_u} \frac{r_{u, i}}{log\left(1 + v_{\hat{D}_n(u)}(i)\right)}}{M}
# $$
# </center>
#
# where:
#   * $r_{u, i}$ is $1$ if there was an interaction between user $u$ and item $i$ in the test set and $0$ otherwise,
#   * $\hat{D}_n(u)$ is the set of the first $n$ recommendations for user $u$,
#   * $v_{\hat{D}_n(u)}(i)$ is the position of item $i$ in recommendations $\hat{D}_n$,
#   * $M$ is the number of users.
#
#
#     - Takes the rank of each recommendation into account.

# %%
def ndcg(recommendations, real_interactions, n=1):
    """
    Assumes recommendations are ordered by user_id and then by score.
    """
    # Transform real_interactions to a dict for a large speed-up
    rui = defaultdict(lambda: 0)
    
    for idx, row in real_interactions.iterrows():
        rui[(row['user_id'], row['item_id'])] = 1
        
    ndcg = 0.0
    
    previous_user_id = -1
    rank = 0
    for idx, row in recommendations.iterrows():
        if previous_user_id == row['user_id']:
            rank += 1
        else:
            rank = 1
            
        if rank <= n:
            ndcg += rui[(row['user_id'], row['item_id'])] / np.log2(1 + rank)
        
        previous_user_id = row['user_id']
    
    ndcg /= len(recommendations['user_id'].unique())
    
    return ndcg

    
recommendations = pd.DataFrame(
    [
        [1, 13, 0.9],
        [1, 45, 0.8],
        [1, 22, 0.71],
        [1, 77, 0.55],
        [1, 9, 0.52],
        [2, 11, 0.85],
        [2, 13, 0.69],
        [2, 25, 0.64],
        [2, 6, 0.60],
        [2, 77, 0.53]
        
    ], columns=['user_id', 'item_id', 'score'])

display(HTML(recommendations.to_html()))

real_interactions = pd.DataFrame(
    [
        [1, 45],
        [1, 22],
        [1, 77],
        [2, 13],
        [2, 77]
        
    ], columns=['user_id', 'item_id'])

display(HTML(real_interactions.to_html()))
    
print("NDCG@3 = {:.4f}".format(ndcg(recommendations, real_interactions, n=3)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>item_id</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>13</td>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>45</td>
#       <td>0.80</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>22</td>
#       <td>0.71</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>77</td>
#       <td>0.55</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>9</td>
#       <td>0.52</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>11</td>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2</td>
#       <td>13</td>
#       <td>0.69</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2</td>
#       <td>25</td>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2</td>
#       <td>6</td>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2</td>
#       <td>77</td>
#       <td>0.53</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>item_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>77</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>77</td>
#     </tr>
#   </tbody>
# </table>
# NDCG@3 = 0.8809

# %% [markdown]
# # Testing routines (offline)

# %% [markdown]
# ## Train and test set split

# %% [markdown]
# ### Explicit feedback

# %%
def evaluate_train_test_split_explicit(recommender, interactions_df, items_df, seed=6789):
    rng = np.random.RandomState(seed=seed)
    
    # Split the dataset into train and test
    
    shuffle = np.arange(len(interactions_df))
    rng.shuffle(shuffle)
    shuffle = list(shuffle)

    train_test_split = 0.8
    split_index = int(len(interactions_df) * train_test_split)

    interactions_df_train = interactions_df.iloc[shuffle[:split_index]]
    interactions_df_test = interactions_df.iloc[shuffle[split_index:]]
    
    # Train the recommender
    
    recommender.fit(interactions_df_train, None, items_df)
    
    # Gather predictions
    
    r_pred = []
    
    for idx, row in interactions_df_test.iterrows():
        users_df = pd.DataFrame([row['user_id']], columns=['user_id'])
        eval_items_df = pd.DataFrame([row['item_id']], columns=['item_id'])
        print(eval_items_df)
        eval_items_df = pd.merge(eval_items_df, items_df, on='item_id')
        print(eval_items_df)
        recommendations = recommender.recommend(users_df, eval_items_df, n_recommendations=1)
        
        r_pred.append(recommendations.iloc[0]['score'])
    
    # Gather real ratings
    
    r_real = np.array(interactions_df_test['rating'].tolist())
    # Return evaluation metrics
    
    return rmse(r_pred, r_real), mre(r_pred, r_real), tre(r_pred, r_real)

recommender = Recommender()

results = [['BaseRecommender'] + list(evaluate_train_test_split_explicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], ml_movies_df))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'RMSE', 'MRE', 'TRE'])

display(HTML(results.to_html()))
# Out:
#    item_id
# 0   3751.0
#    item_id               title                     genres
# 0   3751.0  Chicken Run (2000)  Animation|Children|Comedy
#    item_id
# 0   7438.0
#    item_id                     title                 genres
# 0   7438.0  Kill Bill: Vol. 2 (2004)  Action|Drama|Thriller
#    item_id
# 0  91842.0
#    item_id              title                       genres
# 0  91842.0  Contraband (2012)  Action|Crime|Drama|Thriller
#    item_id
# 0   1500.0
#    item_id                       title                genres
# 0   1500.0  Grosse Pointe Blank (1997)  Comedy|Crime|Romance
#    item_id
# 0   1955.0
#    item_id                     title genres
# 0   1955.0  Kramer vs. Kramer (1979)  Drama
#    item_id
# 0   7438.0
#    item_id                     title                 genres
# 0   7438.0  Kill Bill: Vol. 2 (2004)  Action|Drama|Thriller
#    item_id
# 0   3639.0
#    item_id                                title                     genres
# 0   3639.0  Man with the Golden Gun, The (1974)  Action|Adventure|Thriller
#    item_id
# 0  46578.0
#    item_id                        title                  genres
# 0  46578.0  Little Miss Sunshine (2006)  Adventure|Comedy|Drama
#    item_id
# 0   1213.0
#    item_id              title       genres
# 0   1213.0  Goodfellas (1990)  Crime|Drama
#    item_id
# 0   2108.0
#    item_id              title          genres
# 0   2108.0  L.A. Story (1991)  Comedy|Romance
#    item_id
# 0  27773.0
#    item_id           title            genres
# 0  27773.0  Old Boy (2003)  Mystery|Thriller
#    item_id
# 0   2594.0
#    item_id                                  title  \
# 0   2594.0  Open Your Eyes (Abre los ojos) (1997)
#
#                           genres
# 0  Drama|Romance|Sci-Fi|Thriller
#    item_id
# 0   4002.0
#    item_id                                title  genres
# 0   4002.0  Planes, Trains & Automobiles (1987)  Comedy
#    item_id
# 0   2006.0
#    item_id                      title                 genres
# 0   2006.0  Mask of Zorro, The (1998)  Action|Comedy|Romance
#    item_id
# 0  56775.0
#    item_id                                      title            genres
# 0  56775.0  National Treasure: Book of Secrets (2007)  Action|Adventure
#    item_id
# 0  55272.0
#    item_id                    title       genres
# 0  55272.0  We Own the Night (2007)  Crime|Drama
#    item_id
# 0   5103.0
#    item_id                title                 genres
# 0   5103.0  Sandlot, The (1993)  Children|Comedy|Drama
#    item_id
# 0   8636.0
#    item_id                title                        genres
# 0   8636.0  Spider-Man 2 (2004)  Action|Adventure|Sci-Fi|IMAX
#    item_id
# 0  71341.0
#    item_id                                   title  genres
# 0  71341.0  Blood Creek (a.k.a. Town Creek) (2009)  Horror
#    item_id
# 0    481.0
#    item_id              title          genres
# 0    481.0  Kalifornia (1993)  Drama|Thriller
#    item_id
# 0    585.0
#    item_id                          title  genres
# 0    585.0  Brady Bunch Movie, The (1995)  Comedy
#    item_id
# 0  69844.0
#    item_id                                          title  \
# 0  69844.0  Harry Potter and the Half-Blood Prince (2009)
#
#                                    genres
# 0  Adventure|Fantasy|Mystery|Romance|IMAX
#    item_id
# 0  37741.0
#    item_id          title       genres
# 0  37741.0  Capote (2005)  Crime|Drama
#    item_id
# 0  41566.0
#    item_id                                              title  \
# 0  41566.0  Chronicles of Narnia: The Lion, the Witch and ...
#
#                        genres
# 0  Adventure|Children|Fantasy
#    item_id
# 0   2396.0
#    item_id                       title                genres
# 0   2396.0  Shakespeare in Love (1998)  Comedy|Drama|Romance
#    item_id
# 0   5219.0
#    item_id                 title                         genres
# 0   5219.0  Resident Evil (2002)  Action|Horror|Sci-Fi|Thriller
#    item_id
# 0   7438.0
#    item_id                     title                 genres
# 0   7438.0  Kill Bill: Vol. 2 (2004)  Action|Drama|Thriller
#    item_id
# 0   1704.0
#    item_id                     title         genres
# 0   1704.0  Good Will Hunting (1997)  Drama|Romance
#    item_id
# 0  87869.0
#    item_id                   title        genres
# 0  87869.0  Horrible Bosses (2011)  Comedy|Crime
#    item_id
# 0   2594.0
#    item_id                                  title  \
# 0   2594.0  Open Your Eyes (Abre los ojos) (1997)
#
#                           genres
# 0  Drama|Romance|Sci-Fi|Thriller
#     item_id
# 0  110553.0
#     item_id                            title              genres
# 0  110553.0  The Amazing Spider-Man 2 (2014)  Action|Sci-Fi|IMAX
#    item_id
# 0   2170.0
#    item_id                      title         genres
# 0   2170.0  Wrongfully Accused (1998)  Action|Comedy
#    item_id
# 0  40819.0
#    item_id                 title                 genres
# 0  40819.0  Walk the Line (2005)  Drama|Musical|Romance
#    item_id
# 0    780.0
#    item_id                                 title  \
# 0    780.0  Independence Day (a.k.a. ID4) (1996)
#
#                              genres
# 0  Action|Adventure|Sci-Fi|Thriller
#    item_id
# 0  99114.0
#    item_id                    title                genres
# 0  99114.0  Django Unchained (2012)  Action|Drama|Western
#    item_id
# 0   1704.0
#    item_id                     title         genres
# 0   1704.0  Good Will Hunting (1997)  Drama|Romance
#    item_id
# 0   2713.0
#    item_id               title           genres
# 0   2713.0  Lake Placid (1999)  Horror|Thriller
#    item_id
# 0   3994.0
#    item_id               title        genres
# 0   3994.0  Unbreakable (2000)  Drama|Sci-Fi
#    item_id
# 0   2682.0
#    item_id         title genres
# 0   2682.0  Limbo (1999)  Drama
#    item_id
# 0     12.0
#    item_id                               title         genres
# 0     12.0  Dracula: Dead and Loving It (1995)  Comedy|Horror
#    item_id
# 0   2088.0
#    item_id          title                    genres
# 0   2088.0  Popeye (1980)  Adventure|Comedy|Musical
#    item_id
# 0   1244.0
#    item_id             title                genres
# 0   1244.0  Manhattan (1979)  Comedy|Drama|Romance
#    item_id
# 0    208.0
#    item_id              title                   genres
# 0    208.0  Waterworld (1995)  Action|Adventure|Sci-Fi
#    item_id
# 0   2986.0
#    item_id             title                        genres
# 0   2986.0  RoboCop 2 (1990)  Action|Crime|Sci-Fi|Thriller
#    item_id
# 0    858.0
#    item_id                  title       genres
# 0    858.0  Godfather, The (1972)  Crime|Drama
#    item_id
# 0   4117.0
#    item_id                  title genres
# 0   4117.0  Hope and Glory (1987)  Drama
#    item_id
# 0   8798.0
#    item_id              title                       genres
# 0   8798.0  Collateral (2004)  Action|Crime|Drama|Thriller
#    item_id
# 0    289.0
#    item_id            title          genres
# 0    289.0  Only You (1994)  Comedy|Romance
#    item_id
# 0   6537.0
#    item_id                                      title                   genres
# 0   6537.0  Terminator 3: Rise of the Machines (2003)  Action|Adventure|Sci-Fi
#    item_id
# 0     95.0
#    item_id                title                     genres
# 0     95.0  Broken Arrow (1996)  Action|Adventure|Thriller
#    item_id
# 0  34534.0
#    item_id                 title              genres
# 0  34534.0  Four Brothers (2005)  Action|Crime|Drama
#    item_id
# 0  80489.0
#    item_id             title                genres
# 0  80489.0  Town, The (2010)  Crime|Drama|Thriller
#    item_id
# 0   1213.0
#    item_id              title       genres
# 0   1213.0  Goodfellas (1990)  Crime|Drama
#    item_id
# 0   3396.0
#    item_id                     title                             genres
# 0   3396.0  Muppet Movie, The (1979)  Adventure|Children|Comedy|Musical
#    item_id
# 0  41566.0
#    item_id                                              title  \
# 0  41566.0  Chronicles of Narnia: The Lion, the Witch and ...
#
#                        genres
# 0  Adventure|Children|Fantasy
#    item_id
# 0   2078.0
#    item_id                    title                             genres
# 0   2078.0  Jungle Book, The (1967)  Animation|Children|Comedy|Musical
#    item_id
# 0    595.0
#    item_id                        title  \
# 0    595.0  Beauty and the Beast (1991)
#
#                                             genres
# 0  Animation|Children|Fantasy|Musical|Romance|IMAX
#    item_id
# 0   5103.0
#    item_id                title                 genres
# 0   5103.0  Sandlot, The (1993)  Children|Comedy|Drama
#    item_id
# 0   1225.0
#    item_id           title genres
# 0   1225.0  Amadeus (1984)  Drama
#    item_id
# 0   5568.0
#    item_id                      title  genres
# 0   5568.0  Johnny Dangerously (1984)  Comedy
#    item_id
# 0    180.0
#    item_id            title          genres
# 0    180.0  Mallrats (1995)  Comedy|Romance
#    item_id
# 0    750.0
#    item_id                                              title      genres
# 0    750.0  Dr. Strangelove or: How I Learned to Stop Worr...  Comedy|War
#    item_id
# 0   7438.0
#    item_id                     title                 genres
# 0   7438.0  Kill Bill: Vol. 2 (2004)  Action|Drama|Thriller
#    item_id
# 0  70305.0
#    item_id                          title  \
# 0  70305.0  Race to Witch Mountain (2009)
#
#                                        genres
# 0  Adventure|Children|Fantasy|Sci-Fi|Thriller
#    item_id
# 0    435.0
#    item_id             title         genres
# 0    435.0  Coneheads (1993)  Comedy|Sci-Fi
#    item_id
# 0   2698.0
#    item_id           title  genres
# 0   2698.0  Zone 39 (1997)  Sci-Fi
#    item_id
# 0   3068.0
#    item_id                title         genres
# 0   3068.0  Verdict, The (1982)  Drama|Mystery
#    item_id
# 0   2100.0
#    item_id          title                  genres
# 0   2100.0  Splash (1984)  Comedy|Fantasy|Romance
#    item_id
# 0   3671.0
#    item_id                   title          genres
# 0   3671.0  Blazing Saddles (1974)  Comedy|Western
#    item_id
# 0   1976.0
#    item_id                              title  genres
# 0   1976.0  Friday the 13th Part 3: 3D (1982)  Horror
#     item_id
# 0  115713.0
#     item_id              title                 genres
# 0  115713.0  Ex Machina (2015)  Drama|Sci-Fi|Thriller
#    item_id
# 0  37741.0
#    item_id          title       genres
# 0  37741.0  Capote (2005)  Crime|Drama
#    item_id
# 0  44195.0
#    item_id                         title        genres
# 0  44195.0  Thank You for Smoking (2006)  Comedy|Drama
#    item_id
# 0    837.0
#    item_id           title                   genres
# 0    837.0  Matilda (1996)  Children|Comedy|Fantasy
#    item_id
# 0   2716.0
#    item_id                                       title                genres
# 0   2716.0  Ghostbusters (a.k.a. Ghost Busters) (1984)  Action|Comedy|Sci-Fi
#    item_id
# 0   8366.0
#    item_id          title        genres
# 0   8366.0  Saved! (2004)  Comedy|Drama
#    item_id
# 0   5954.0
#    item_id             title       genres
# 0   5954.0  25th Hour (2002)  Crime|Drama
#    item_id
# 0   3355.0
#    item_id                   title                           genres
# 0   3355.0  Ninth Gate, The (1999)  Fantasy|Horror|Mystery|Thriller
#    item_id
# 0   3668.0
#    item_id                    title         genres
# 0   3668.0  Romeo and Juliet (1968)  Drama|Romance
#     item_id
# 0  158872.0
#     item_id                 title            genres
# 0  158872.0  Sausage Party (2016)  Animation|Comedy
#    item_id
# 0    930.0
#    item_id             title                      genres
# 0    930.0  Notorious (1946)  Film-Noir|Romance|Thriller
#    item_id
# 0    842.0
#    item_id                                              title         genres
# 0    842.0  Tales from the Crypt Presents: Bordello of Blo...  Comedy|Horror
#    item_id
# 0   2790.0
#    item_id                                              title           genres
# 0   2790.0  Final Conflict, The (a.k.a. Omen III: The Fina...  Horror|Thriller
#    item_id
# 0   7438.0
#    item_id                     title                 genres
# 0   7438.0  Kill Bill: Vol. 2 (2004)  Action|Drama|Thriller
#    item_id
# 0  68358.0
#    item_id             title                        genres
# 0  68358.0  Star Trek (2009)  Action|Adventure|Sci-Fi|IMAX
#    item_id
# 0   2311.0
#    item_id                                  title  genres
# 0   2311.0  2010: The Year We Make Contact (1984)  Sci-Fi
#    item_id
# 0    595.0
#    item_id                        title  \
# 0    595.0  Beauty and the Beast (1991)
#
#                                             genres
# 0  Animation|Children|Fantasy|Musical|Romance|IMAX
#     item_id
# 0  122916.0
#     item_id                  title                   genres
# 0  122916.0  Thor: Ragnarok (2017)  Action|Adventure|Sci-Fi
#    item_id
# 0   3751.0
#    item_id               title                     genres
# 0   3751.0  Chicken Run (2000)  Animation|Children|Comedy
#     item_id
# 0  158398.0
#     item_id                  title  genres
# 0  158398.0  World of Glory (1991)  Comedy
#    item_id
# 0    337.0
#    item_id                               title genres
# 0    337.0  What's Eating Gilbert Grape (1993)  Drama
#    item_id
# 0  56801.0
#    item_id                                       title                genres
# 0  56801.0  AVPR: Aliens vs. Predator - Requiem (2007)  Action|Horror|Sci-Fi
#    item_id
# 0    750.0
#    item_id                                              title      genres
# 0    750.0  Dr. Strangelove or: How I Learned to Stop Worr...  Comedy|War
#    item_id
# 0   3497.0
#    item_id                     title  genres
# 0   3497.0  Max Dugan Returns (1983)  Comedy
#    item_id
# 0     50.0
#    item_id                       title                  genres
# 0     50.0  Usual Suspects, The (1995)  Crime|Mystery|Thriller
#    item_id
# 0   1439.0
#    item_id                     title  genres
# 0   1439.0  Meet Wally Sparks (1997)  Comedy
#    item_id
# 0   1203.0
#    item_id                title genres
# 0   1203.0  12 Angry Men (1957)  Drama
#    item_id
# 0  64575.0
#    item_id         title         genres
# 0  64575.0  Doubt (2008)  Drama|Mystery
#    item_id
# 0    750.0
#    item_id                                              title      genres
# 0    750.0  Dr. Strangelove or: How I Learned to Stop Worr...  Comedy|War
#    item_id
# 0   2000.0
#    item_id                 title                     genres
# 0   2000.0  Lethal Weapon (1987)  Action|Comedy|Crime|Drama
#    item_id
# 0   2065.0
#    item_id                             title                        genres
# 0   2065.0  Purple Rose of Cairo, The (1985)  Comedy|Drama|Fantasy|Romance
#    item_id
# 0   1203.0
#    item_id                title genres
# 0   1203.0  12 Angry Men (1957)  Drama
#    item_id
# 0   6713.0
#    item_id                                    title                   genres
# 0   6713.0  Millennium Actress (Sennen joyû) (2001)  Animation|Drama|Romance
#    item_id
# 0   7438.0
#    item_id                     title                 genres
# 0   7438.0  Kill Bill: Vol. 2 (2004)  Action|Drama|Thriller
#    item_id
# 0     50.0
#    item_id                       title                  genres
# 0     50.0  Usual Suspects, The (1995)  Crime|Mystery|Thriller
#    item_id
# 0   3067.0
#    item_id                                              title        genres
# 0   3067.0  Women on the Verge of a Nervous Breakdown (Muj...  Comedy|Drama
#    item_id
# 0   4954.0
#    item_id                                      title        genres
# 0   4954.0  Ocean's Eleven (a.k.a. Ocean's 11) (1960)  Comedy|Crime
#     item_id
# 0  106072.0
#     item_id                        title                         genres
# 0  106072.0  Thor: The Dark World (2013)  Action|Adventure|Fantasy|IMAX
#    item_id
# 0    188.0
#    item_id                 title                  genres
# 0    188.0  Prophecy, The (1995)  Fantasy|Horror|Mystery
#    item_id
# 0   6100.0
#    item_id                                   title          genres
# 0   6100.0  Midsummer Night's Sex Comedy, A (1982)  Comedy|Romance
#    item_id
# 0   5464.0
#    item_id                     title       genres
# 0   5464.0  Road to Perdition (2002)  Crime|Drama
#    item_id
# 0  39292.0
#    item_id                              title       genres
# 0  39292.0  Good Night, and Good Luck. (2005)  Crime|Drama
#    item_id
# 0   3986.0
#    item_id                title                  genres
# 0   3986.0  6th Day, The (2000)  Action|Sci-Fi|Thriller
#    item_id
# 0   3507.0
#    item_id                   title  genres
# 0   3507.0  Odd Couple, The (1968)  Comedy
#    item_id
# 0    266.0
#    item_id                       title                     genres
# 0    266.0  Legends of the Fall (1994)  Drama|Romance|War|Western
#    item_id
# 0   3006.0
#    item_id                title          genres
# 0   3006.0  Insider, The (1999)  Drama|Thriller
#    item_id
# 0   1704.0
#    item_id                     title         genres
# 0   1704.0  Good Will Hunting (1997)  Drama|Romance
#    item_id
# 0    750.0
#    item_id                                              title      genres
# 0    750.0  Dr. Strangelove or: How I Learned to Stop Worr...  Comedy|War
#    item_id
# 0   1172.0
#    item_id                                           title genres
# 0   1172.0  Cinema Paradiso (Nuovo cinema Paradiso) (1989)  Drama
#    item_id
# 0    858.0
#    item_id                  title       genres
# 0    858.0  Godfather, The (1972)  Crime|Drama
#    item_id
# 0   2052.0
#    item_id               title                          genres
# 0   2052.0  Hocus Pocus (1993)  Children|Comedy|Fantasy|Horror
#    item_id
# 0   3473.0
#    item_id                                              title  genres
# 0   3473.0  Jonah Who Will Be 25 in the Year 2000 (Jonas q...  Comedy
#    item_id
# 0    208.0
#    item_id              title                   genres
# 0    208.0  Waterworld (1995)  Action|Adventure|Sci-Fi
#    item_id
# 0     50.0
#    item_id                       title                  genres
# 0     50.0  Usual Suspects, The (1995)  Crime|Mystery|Thriller
#    item_id
# 0   2671.0
#    item_id                title          genres
# 0   2671.0  Notting Hill (1999)  Comedy|Romance
#    item_id
# 0   5502.0
#    item_id         title                  genres
# 0   5502.0  Signs (2002)  Horror|Sci-Fi|Thriller
#    item_id
# 0  95510.0
#    item_id                           title                        genres
# 0  95510.0  Amazing Spider-Man, The (2012)  Action|Adventure|Sci-Fi|IMAX
#    item_id
# 0   5364.0
#    item_id              title          genres
# 0   5364.0  Unfaithful (2002)  Drama|Thriller
#    item_id
# 0  41566.0
#    item_id                                              title  \
# 0  41566.0  Chronicles of Narnia: The Lion, the Witch and ...
#
#                        genres
# 0  Adventure|Children|Fantasy
#    item_id
# 0   1777.0
#    item_id                       title          genres
# 0   1777.0  Wedding Singer, The (1998)  Comedy|Romance
#    item_id
# 0   6881.0
#    item_id                   title        genres
# 0   6881.0  Pieces of April (2003)  Comedy|Drama
#    item_id
# 0  64575.0
#    item_id         title         genres
# 0  64575.0  Doubt (2008)  Drama|Mystery
#    item_id
# 0   3507.0
#    item_id                   title  genres
# 0   3507.0  Odd Couple, The (1968)  Comedy
#    item_id
# 0   1213.0
#    item_id              title       genres
# 0   1213.0  Goodfellas (1990)  Crime|Drama
#    item_id
# 0   4259.0
#    item_id                       title         genres
# 0   4259.0  Luzhin Defence, The (2000)  Drama|Romance
#    item_id
# 0   2116.0
#    item_id                          title  \
# 0   2116.0  Lord of the Rings, The (1978)
#
#                                  genres
# 0  Adventure|Animation|Children|Fantasy
#    item_id
# 0   5103.0
#    item_id                title                 genres
# 0   5103.0  Sandlot, The (1993)  Children|Comedy|Drama
#    item_id
# 0   3396.0
#    item_id                     title                             genres
# 0   3396.0  Muppet Movie, The (1979)  Adventure|Children|Comedy|Musical
#    item_id
# 0   8798.0
#    item_id              title                       genres
# 0   8798.0  Collateral (2004)  Action|Crime|Drama|Thriller
#    item_id
# 0  47382.0
#    item_id           title         genres
# 0  47382.0  Step Up (2006)  Drama|Romance
#    item_id
# 0   3714.0
#    item_id                 title genres
# 0   3714.0  Clara's Heart (1988)  Drama
#    item_id
# 0   3524.0
#    item_id          title          genres
# 0   3524.0  Arthur (1981)  Comedy|Romance
#    item_id
# 0    586.0
#    item_id              title           genres
# 0    586.0  Home Alone (1990)  Children|Comedy
#    item_id
# 0    208.0
#    item_id              title                   genres
# 0    208.0  Waterworld (1995)  Action|Adventure|Sci-Fi
#     item_id
# 0  176371.0
#     item_id                     title  genres
# 0  176371.0  Blade Runner 2049 (2017)  Sci-Fi
#    item_id
# 0   1704.0
#    item_id                     title         genres
# 0   1704.0  Good Will Hunting (1997)  Drama|Romance
#    item_id
# 0   2420.0
#    item_id                   title genres
# 0   2420.0  Karate Kid, The (1984)  Drama
#    item_id
# 0    343.0
#    item_id                          title    genres
# 0    343.0  Baby-Sitters Club, The (1995)  Children
#     item_id
# 0  179813.0
#     item_id       title genres
# 0  179813.0  LBJ (2017)  Drama
#    item_id
# 0   5673.0
#    item_id                    title                genres
# 0   5673.0  Punch-Drunk Love (2002)  Comedy|Drama|Romance
#    item_id
# 0   2100.0
#    item_id          title                  genres
# 0   2100.0  Splash (1984)  Comedy|Fantasy|Romance
#    item_id
# 0  47099.0
#    item_id                             title genres
# 0  47099.0  Pursuit of Happyness, The (2006)  Drama
#    item_id
# 0    289.0
#    item_id            title          genres
# 0    289.0  Only You (1994)  Comedy|Romance
#    item_id
# 0    267.0
#    item_id               title  genres
# 0    267.0  Major Payne (1995)  Comedy
#    item_id
# 0   3536.0
#    item_id                     title                genres
# 0   3536.0  Keeping the Faith (2000)  Comedy|Drama|Romance
#    item_id
# 0     78.0
#    item_id                       title                       genres
# 0     78.0  Crossing Guard, The (1995)  Action|Crime|Drama|Thriller
#    item_id
# 0   2110.0
#    item_id                             title                 genres
# 0   2110.0  Dead Men Don't Wear Plaid (1982)  Comedy|Crime|Thriller
#    item_id
# 0   1012.0
#    item_id              title          genres
# 0   1012.0  Old Yeller (1957)  Children|Drama
#    item_id
# 0    145.0
#    item_id            title                              genres
# 0    145.0  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller
#    item_id
# 0  71899.0
#    item_id                title                  genres
# 0  71899.0  Mary and Max (2009)  Animation|Comedy|Drama
#    item_id
# 0     50.0
#    item_id                       title                  genres
# 0     50.0  Usual Suspects, The (1995)  Crime|Mystery|Thriller
#    item_id
# 0   1225.0
#    item_id           title genres
# 0   1225.0  Amadeus (1984)  Drama
#    item_id
# 0    423.0
#    item_id              title           genres
# 0    423.0  Blown Away (1994)  Action|Thriller
#     item_id
# 0  180031.0
#     item_id                      title                   genres
# 0  180031.0  The Shape of Water (2017)  Adventure|Drama|Fantasy
#    item_id
# 0   4255.0
#    item_id                       title  genres
# 0   4255.0  Freddy Got Fingered (2001)  Comedy
#    item_id
# 0   6688.0
#    item_id                             title        genres
# 0   6688.0  Autumn Spring (Babí léto) (2001)  Comedy|Drama
#    item_id
# 0  67295.0
#    item_id                                              title  \
# 0  67295.0  Kung Fu Panda: Secrets of the Furious Five (2008)
#
#                              genres
# 0  Action|Animation|Children|Comedy
#    item_id
# 0  48738.0
#    item_id                              title          genres
# 0  48738.0  Last King of Scotland, The (2006)  Drama|Thriller
#    item_id
# 0   7451.0
#    item_id              title  genres
# 0   7451.0  Mean Girls (2004)  Comedy
#    item_id
# 0    780.0
#    item_id                                 title  \
# 0    780.0  Independence Day (a.k.a. ID4) (1996)
#
#                              genres
# 0  Action|Adventure|Sci-Fi|Thriller
#    item_id
# 0  41627.0
#    item_id                                              title        genres
# 0  41627.0  Samurai Rebellion (Jôi-uchi: Hairyô tsuma shim...  Action|Drama
#    item_id
# 0   1213.0
#    item_id              title       genres
# 0   1213.0  Goodfellas (1990)  Crime|Drama
#    item_id
# 0    930.0
#    item_id             title                      genres
# 0    930.0  Notorious (1946)  Film-Noir|Romance|Thriller
#    item_id
# 0  88744.0
#    item_id                                  title  \
# 0  88744.0  Rise of the Planet of the Apes (2011)
#
#                          genres
# 0  Action|Drama|Sci-Fi|Thriller
#    item_id
# 0    207.0
#    item_id                         title         genres
# 0    207.0  Walk in the Clouds, A (1995)  Drama|Romance
#    item_id
# 0  88744.0
#    item_id                                  title  \
# 0  88744.0  Rise of the Planet of the Apes (2011)
#
#                          genres
# 0  Action|Drama|Sci-Fi|Thriller
#    item_id
# 0   6039.0
#    item_id                     title          genres
# 0   6039.0  Woman in Red, The (1984)  Comedy|Romance
#    item_id
# 0   6502.0
#    item_id                 title                genres
# 0   6502.0  28 Days Later (2002)  Action|Horror|Sci-Fi
#    item_id
# 0  99114.0
#    item_id                    title                genres
# 0  99114.0  Django Unchained (2012)  Action|Drama|Western
#    item_id
# 0    809.0
#    item_id        title            genres
# 0    809.0  Fled (1996)  Action|Adventure
#    item_id
# 0   2420.0
#    item_id                   title genres
# 0   2420.0  Karate Kid, The (1984)  Drama
#    item_id
# 0  30810.0
#    item_id                                       title  \
# 0  30810.0  Life Aquatic with Steve Zissou, The (2004)
#
#                      genres
# 0  Adventure|Comedy|Fantasy
#    item_id
# 0  30810.0
#    item_id                                       title  \
# 0  30810.0  Life Aquatic with Steve Zissou, The (2004)
#
#                      genres
# 0  Adventure|Comedy|Fantasy
#    item_id
# 0   3994.0
#    item_id               title        genres
# 0   3994.0  Unbreakable (2000)  Drama|Sci-Fi
#    item_id
# 0   2313.0
#    item_id                     title genres
# 0   2313.0  Elephant Man, The (1980)  Drama
#    item_id
# 0     95.0
#    item_id                title                     genres
# 0     95.0  Broken Arrow (1996)  Action|Adventure|Thriller
#    item_id
# 0   2100.0
#    item_id          title                  genres
# 0   2100.0  Splash (1984)  Comedy|Fantasy|Romance
#    item_id
# 0   8644.0
#    item_id            title                            genres
# 0   8644.0  I, Robot (2004)  Action|Adventure|Sci-Fi|Thriller
#    item_id
# 0    180.0
#    item_id            title          genres
# 0    180.0  Mallrats (1995)  Comedy|Romance
#    item_id
# 0   2000.0
#    item_id                 title                     genres
# 0   2000.0  Lethal Weapon (1987)  Action|Comedy|Crime|Drama
#    item_id
# 0    405.0
#    item_id                                              title          genres
# 0    405.0  Highlander III: The Sorcerer (a.k.a. Highlande...  Action|Fantasy
#    item_id
# 0    145.0
#    item_id            title                              genres
# 0    145.0  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller
#    item_id
# 0    145.0
#    item_id            title                              genres
# 0    145.0  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller
#    item_id
# 0    858.0
#    item_id                  title       genres
# 0    858.0  Godfather, The (1972)  Crime|Drama
#    item_id
# 0   2006.0
#    item_id                      title                 genres
# 0   2006.0  Mask of Zorro, The (1998)  Action|Comedy|Romance
#    item_id
# 0   2947.0
#    item_id              title                     genres
# 0   2947.0  Goldfinger (1964)  Action|Adventure|Thriller
#    item_id
# 0   2420.0
#    item_id                   title genres
# 0   2420.0  Karate Kid, The (1984)  Drama
#    item_id
# 0   3524.0
#    item_id          title          genres
# 0   3524.0  Arthur (1981)  Comedy|Romance
#     item_id
# 0  119145.0
#     item_id                                title  \
# 0  119145.0  Kingsman: The Secret Service (2015)
#
#                           genres
# 0  Action|Adventure|Comedy|Crime
#    item_id
# 0  80489.0
#    item_id             title                genres
# 0  80489.0  Town, The (2010)  Crime|Drama|Thriller
#    item_id
# 0    842.0
#    item_id                                              title         genres
# 0    842.0  Tales from the Crypt Presents: Bordello of Blo...  Comedy|Horror
#    item_id
# 0   7438.0
#    item_id                     title                 genres
# 0   7438.0  Kill Bill: Vol. 2 (2004)  Action|Drama|Thriller
#     item_id
# 0  176371.0
#     item_id                     title  genres
# 0  176371.0  Blade Runner 2049 (2017)  Sci-Fi
#    item_id
# 0   2692.0
#    item_id                             title        genres
# 0   2692.0  Run Lola Run (Lola rennt) (1998)  Action|Crime
#    item_id
# 0  68358.0
#    item_id             title                        genres
# 0  68358.0  Star Trek (2009)  Action|Adventure|Sci-Fi|IMAX
#    item_id
# 0    435.0
#    item_id             title         genres
# 0    435.0  Coneheads (1993)  Comedy|Sci-Fi
#    item_id
# 0   3671.0
#    item_id                   title          genres
# 0   3671.0  Blazing Saddles (1974)  Comedy|Western
#    item_id
# 0    170.0
#    item_id           title                           genres
# 0    170.0  Hackers (1995)  Action|Adventure|Crime|Thriller
#    item_id
# 0    543.0
#    item_id                                title                   genres
# 0    543.0  So I Married an Axe Murderer (1993)  Comedy|Romance|Thriller
#    item_id
# 0  68358.0
#    item_id             title                        genres
# 0  68358.0  Star Trek (2009)  Action|Adventure|Sci-Fi|IMAX
#     item_id
# 0  114818.0
#     item_id           title               genres
# 0  114818.0  Stretch (2014)  Action|Comedy|Crime
#    item_id
# 0   6537.0
#    item_id                                      title                   genres
# 0   6537.0  Terminator 3: Rise of the Machines (2003)  Action|Adventure|Sci-Fi
#     item_id
# 0  119145.0
#     item_id                                title  \
# 0  119145.0  Kingsman: The Secret Service (2015)
#
#                           genres
# 0  Action|Adventure|Comedy|Crime
#    item_id
# 0  60684.0
#    item_id            title                                     genres
# 0  60684.0  Watchmen (2009)  Action|Drama|Mystery|Sci-Fi|Thriller|IMAX
#    item_id
# 0   2010.0
#    item_id              title        genres
# 0   2010.0  Metropolis (1927)  Drama|Sci-Fi
#    item_id
# 0   2986.0
#    item_id             title                        genres
# 0   2986.0  RoboCop 2 (1990)  Action|Crime|Sci-Fi|Thriller
#    item_id
# 0      4.0
#    item_id                     title                genres
# 0      4.0  Waiting to Exhale (1995)  Comedy|Drama|Romance
#    item_id
# 0  32596.0
#    item_id          title                   genres
# 0  32596.0  Sahara (2005)  Action|Adventure|Comedy
#    item_id
# 0  53000.0
#    item_id                  title                  genres
# 0  53000.0  28 Weeks Later (2007)  Horror|Sci-Fi|Thriller
#    item_id
# 0   4349.0
#    item_id            title      genres
# 0   4349.0  Catch-22 (1970)  Comedy|War
#    item_id
# 0   7360.0
#    item_id                    title                        genres
# 0   7360.0  Dawn of the Dead (2004)  Action|Drama|Horror|Thriller
#    item_id
# 0    337.0
#    item_id                               title genres
# 0    337.0  What's Eating Gilbert Grape (1993)  Drama
#    item_id
# 0    858.0
#    item_id                  title       genres
# 0    858.0  Godfather, The (1972)  Crime|Drama
#    item_id
# 0  66915.0
#    item_id                 title                                genres
# 0  66915.0  Rock-A-Doodle (1991)  Adventure|Animation|Children|Musical
#    item_id
# 0   1021.0
#    item_id                          title           genres
# 0   1021.0  Angels in the Outfield (1994)  Children|Comedy
#    item_id
# 0   4896.0
#    item_id                                              title  \
# 0   4896.0  Harry Potter and the Sorcerer's Stone (a.k.a. ...
#
#                        genres
# 0  Adventure|Children|Fantasy
#    item_id
# 0   7451.0
#    item_id              title  genres
# 0   7451.0  Mean Girls (2004)  Comedy
#    item_id
# 0   6058.0
#    item_id                       title           genres
# 0   6058.0  Final Destination 2 (2003)  Horror|Thriller
#    item_id
# 0   8636.0
#    item_id                title                        genres
# 0   8636.0  Spider-Man 2 (2004)  Action|Adventure|Sci-Fi|IMAX
#    item_id
# 0    188.0
#    item_id                 title                  genres
# 0    188.0  Prophecy, The (1995)  Fantasy|Horror|Mystery
#    item_id
# 0    543.0
#    item_id                                title                   genres
# 0    543.0  So I Married an Axe Murderer (1993)  Comedy|Romance|Thriller
#    item_id
# 0   2289.0
#    item_id               title              genres
# 0   2289.0  Player, The (1992)  Comedy|Crime|Drama
#    item_id
# 0   3536.0
#    item_id                     title                genres
# 0   3536.0  Keeping the Faith (2000)  Comedy|Drama|Romance
#    item_id
# 0   2952.0
#    item_id                       title                genres
# 0   2952.0  Sydney (Hard Eight) (1996)  Crime|Drama|Thriller
#    item_id
# 0    379.0
#    item_id           title                  genres
# 0    379.0  Timecop (1994)  Action|Sci-Fi|Thriller
#    item_id
# 0   2716.0
#    item_id                                       title                genres
# 0   2716.0  Ghostbusters (a.k.a. Ghost Busters) (1984)  Action|Comedy|Sci-Fi
#    item_id
# 0    233.0
#    item_id           title genres
# 0    233.0  Exotica (1994)  Drama
#    item_id
# 0   1976.0
#    item_id                              title  genres
# 0   1976.0  Friday the 13th Part 3: 3D (1982)  Horror
#    item_id
# 0   7438.0
#    item_id                     title                 genres
# 0   7438.0  Kill Bill: Vol. 2 (2004)  Action|Drama|Thriller
#    item_id
# 0   2065.0
#    item_id                             title                        genres
# 0   2065.0  Purple Rose of Cairo, The (1985)  Comedy|Drama|Fantasy|Romance
#    item_id
# 0   7438.0
#    item_id                     title                 genres
# 0   7438.0  Kill Bill: Vol. 2 (2004)  Action|Drama|Thriller
#    item_id
# 0   2502.0
#    item_id                title        genres
# 0   2502.0  Office Space (1999)  Comedy|Crime
#    item_id
# 0   2502.0
#    item_id                title        genres
# 0   2502.0  Office Space (1999)  Comedy|Crime
#    item_id
# 0     50.0
#    item_id                       title                  genres
# 0     50.0  Usual Suspects, The (1995)  Crime|Mystery|Thriller
#    item_id
# 0  41566.0
#    item_id                                              title  \
# 0  41566.0  Chronicles of Narnia: The Lion, the Witch and ...
#
#                        genres
# 0  Adventure|Children|Fantasy
#    item_id
# 0   5219.0
#    item_id                 title                         genres
# 0   5219.0  Resident Evil (2002)  Action|Horror|Sci-Fi|Thriller
#    item_id
# 0    780.0
#    item_id                                 title  \
# 0    780.0  Independence Day (a.k.a. ID4) (1996)
#
#                              genres
# 0  Action|Adventure|Sci-Fi|Thriller
#    item_id
# 0   3668.0
#    item_id                    title         genres
# 0   3668.0  Romeo and Juliet (1968)  Drama|Romance
#    item_id
# 0    232.0
#    item_id                                        title                genres
# 0    232.0  Eat Drink Man Woman (Yin shi nan nu) (1994)  Comedy|Drama|Romance
#    item_id
# 0    266.0
#    item_id                       title                     genres
# 0    266.0  Legends of the Fall (1994)  Drama|Romance|War|Western
#    item_id
# 0  53138.0
#    item_id                                              title  \
# 0  53138.0  Librarian: Return to King Solomon's Mines, The...
#
#                      genres
# 0  Action|Adventure|Fantasy
#    item_id
# 0   1704.0
#    item_id                     title         genres
# 0   1704.0  Good Will Hunting (1997)  Drama|Romance
#    item_id
# 0   2502.0
#    item_id                title        genres
# 0   2502.0  Office Space (1999)  Comedy|Crime
#    item_id
# 0     50.0
#    item_id                       title                  genres
# 0     50.0  Usual Suspects, The (1995)  Crime|Mystery|Thriller
#    item_id
# 0   3479.0
#    item_id             title                     genres
# 0   3479.0  Ladyhawke (1985)  Adventure|Fantasy|Romance
#    item_id
# 0   5673.0
#    item_id                    title                genres
# 0   5673.0  Punch-Drunk Love (2002)  Comedy|Drama|Romance
#    item_id
# 0    595.0
#    item_id                        title  \
# 0    595.0  Beauty and the Beast (1991)
#
#                                             genres
# 0  Animation|Children|Fantasy|Musical|Romance|IMAX
#    item_id
# 0  41566.0
#    item_id                                              title  \
# 0  41566.0  Chronicles of Narnia: The Lion, the Witch and ...
#
#                        genres
# 0  Adventure|Children|Fantasy
#    item_id
# 0   1381.0
#    item_id            title                  genres
# 0   1381.0  Grease 2 (1982)  Comedy|Musical|Romance
#    item_id
# 0   1704.0
#    item_id                     title         genres
# 0   1704.0  Good Will Hunting (1997)  Drama|Romance
#    item_id
# 0   1203.0
#    item_id                title genres
# 0   1203.0  12 Angry Men (1957)  Drama
#    item_id
# 0  27773.0
#    item_id           title            genres
# 0  27773.0  Old Boy (2003)  Mystery|Thriller
#     item_id
# 0  176371.0
#     item_id                     title  genres
# 0  176371.0  Blade Runner 2049 (2017)  Sci-Fi
#    item_id
# 0  95510.0
#    item_id                           title                        genres
# 0  95510.0  Amazing Spider-Man, The (2012)  Action|Adventure|Sci-Fi|IMAX
#    item_id
# 0    788.0
#    item_id                        title                         genres
# 0    788.0  Nutty Professor, The (1996)  Comedy|Fantasy|Romance|Sci-Fi
#    item_id
# 0   1777.0
#    item_id                       title          genres
# 0   1777.0  Wedding Singer, The (1998)  Comedy|Romance
#    item_id
# 0   5673.0
#    item_id                    title                genres
# 0   5673.0  Punch-Drunk Love (2002)  Comedy|Drama|Romance
#    item_id
# 0   1500.0
#    item_id                       title                genres
# 0   1500.0  Grosse Pointe Blank (1997)  Comedy|Crime|Romance
#    item_id
# 0    858.0
#    item_id                  title       genres
# 0    858.0  Godfather, The (1972)  Crime|Drama
#    item_id
# 0  76738.0
#    item_id                                 title       genres
# 0  76738.0  Steam of Life (Miesten vuoro) (2010)  Documentary
#    item_id
# 0   1213.0
#    item_id              title       genres
# 0   1213.0  Goodfellas (1990)  Crime|Drama
#    item_id
# 0    435.0
#    item_id             title         genres
# 0    435.0  Coneheads (1993)  Comedy|Sci-Fi
#    item_id
# 0  90746.0
#    item_id                             title                         genres
# 0  90746.0  Adventures of Tintin, The (2011)  Action|Animation|Mystery|IMAX
#    item_id
# 0   4239.0
#    item_id        title       genres
# 0   4239.0  Blow (2001)  Crime|Drama
#    item_id
# 0   2313.0
#    item_id                     title genres
# 0   2313.0  Elephant Man, The (1980)  Drama
#    item_id
# 0   2860.0
#    item_id               title  genres
# 0   2860.0  Blue Streak (1999)  Comedy
#    item_id
# 0   3668.0
#    item_id                    title         genres
# 0   3668.0  Romeo and Juliet (1968)  Drama|Romance
#    item_id
# 0    750.0
#    item_id                                              title      genres
# 0    750.0  Dr. Strangelove or: How I Learned to Stop Worr...  Comedy|War
#    item_id
# 0  37741.0
#    item_id          title       genres
# 0  37741.0  Capote (2005)  Crime|Drama
#    item_id
# 0   4002.0
#    item_id                                title  genres
# 0   4002.0  Planes, Trains & Automobiles (1987)  Comedy
#    item_id
# 0  41573.0
#    item_id                     title                genres
# 0  41573.0  Family Stone, The (2005)  Comedy|Drama|Romance
#    item_id
# 0   1976.0
#    item_id                              title  genres
# 0   1976.0  Friday the 13th Part 3: 3D (1982)  Horror
#     item_id
# 0  158872.0
#     item_id                 title            genres
# 0  158872.0  Sausage Party (2016)  Animation|Comedy
#    item_id
# 0  56775.0
#    item_id                                      title            genres
# 0  56775.0  National Treasure: Book of Secrets (2007)  Action|Adventure
#    item_id
# 0  53972.0
#    item_id                         title                           genres
# 0  53972.0  Live Free or Die Hard (2007)  Action|Adventure|Crime|Thriller
#    item_id
# 0     95.0
#    item_id                title                     genres
# 0     95.0  Broken Arrow (1996)  Action|Adventure|Thriller
#    item_id
# 0   1184.0
#    item_id                title        genres
# 0   1184.0  Mediterraneo (1991)  Comedy|Drama
#    item_id
# 0   2110.0
#    item_id                             title                 genres
# 0   2110.0  Dead Men Don't Wear Plaid (1982)  Comedy|Crime|Thriller
#    item_id
# 0    337.0
#    item_id                               title genres
# 0    337.0  What's Eating Gilbert Grape (1993)  Drama
#    item_id
# 0   6537.0
#    item_id                                      title                   genres
# 0   6537.0  Terminator 3: Rise of the Machines (2003)  Action|Adventure|Sci-Fi
#    item_id
# 0  94494.0
#    item_id               title          genres
# 0  94494.0  96 Minutes (2011)   Drama|Thriller
#    item_id
# 0  83349.0
#    item_id                     title  \
# 0  83349.0  Green Hornet, The (2011)
#
#                                       genres
# 0  Action|Comedy|Crime|Fantasy|Thriller|IMAX
#    item_id
# 0    750.0
#    item_id                                              title      genres
# 0    750.0  Dr. Strangelove or: How I Learned to Stop Worr...  Comedy|War
#    item_id
# 0     50.0
#    item_id                       title                  genres
# 0     50.0  Usual Suspects, The (1995)  Crime|Mystery|Thriller
#    item_id
# 0   1033.0
#    item_id                          title                    genres
# 0   1033.0  Fox and the Hound, The (1981)  Animation|Children|Drama
#    item_id
# 0   1777.0
#    item_id                       title          genres
# 0   1777.0  Wedding Singer, The (1998)  Comedy|Romance
#     item_id
# 0  104837.0
#     item_id                 title        genres
# 0  104837.0  Rage of Honor (1987)  Action|Crime
#    item_id
# 0   3882.0
#    item_id               title  genres
# 0   3882.0  Bring It On (2000)  Comedy
#    item_id
# 0   8340.0
#    item_id                        title          genres
# 0   8340.0  Escape from Alcatraz (1979)  Drama|Thriller
#    item_id
# 0   1704.0
#    item_id                     title         genres
# 0   1704.0  Good Will Hunting (1997)  Drama|Romance
#    item_id
# 0   2135.0
#    item_id                   title                      genres
# 0   2135.0  Doctor Dolittle (1967)  Adventure|Children|Musical
#    item_id
# 0   3591.0
#    item_id           title        genres
# 0   3591.0  Mr. Mom (1983)  Comedy|Drama
#    item_id
# 0   3994.0
#    item_id               title        genres
# 0   3994.0  Unbreakable (2000)  Drama|Sci-Fi
#    item_id
# 0  30810.0
#    item_id                                       title  \
# 0  30810.0  Life Aquatic with Steve Zissou, The (2004)
#
#                      genres
# 0  Adventure|Comedy|Fantasy
#    item_id
# 0  69844.0
#    item_id                                          title  \
# 0  69844.0  Harry Potter and the Half-Blood Prince (2009)
#
#                                    genres
# 0  Adventure|Fantasy|Mystery|Romance|IMAX
#    item_id
# 0   4896.0
#    item_id                                              title  \
# 0   4896.0  Harry Potter and the Sorcerer's Stone (a.k.a. ...
#
#                        genres
# 0  Adventure|Children|Fantasy
#    item_id
# 0   2396.0
#    item_id                       title                genres
# 0   2396.0  Shakespeare in Love (1998)  Comedy|Drama|Romance
#    item_id
# 0    248.0
#    item_id              title  genres
# 0    248.0  Houseguest (1994)  Comedy
#    item_id
# 0    780.0
#    item_id                                 title  \
# 0    780.0  Independence Day (a.k.a. ID4) (1996)
#
#                              genres
# 0  Action|Adventure|Sci-Fi|Thriller
#    item_id
# 0    858.0
#    item_id                  title       genres
# 0    858.0  Godfather, The (1972)  Crime|Drama
#    item_id
# 0    959.0
#    item_id                    title genres
# 0    959.0  Of Human Bondage (1934)  Drama
#    item_id
# 0   6502.0
#    item_id                 title                genres
# 0   6502.0  28 Days Later (2002)  Action|Horror|Sci-Fi
#    item_id
# 0   4896.0
#    item_id                                              title  \
# 0   4896.0  Harry Potter and the Sorcerer's Stone (a.k.a. ...
#
#                        genres
# 0  Adventure|Children|Fantasy
#    item_id
# 0   6502.0
#    item_id                 title                genres
# 0   6502.0  28 Days Later (2002)  Action|Horror|Sci-Fi
#    item_id
# 0    585.0
#    item_id                          title  genres
# 0    585.0  Brady Bunch Movie, The (1995)  Comedy
#    item_id
# 0    460.0
#    item_id                         title  genres
# 0    460.0  Getting Even with Dad (1994)  Comedy
#    item_id
# 0   2989.0
#    item_id                      title                     genres
# 0   2989.0  For Your Eyes Only (1981)  Action|Adventure|Thriller
#    item_id
# 0   2110.0
#    item_id                             title                 genres
# 0   2110.0  Dead Men Don't Wear Plaid (1982)  Comedy|Crime|Thriller
#     item_id
# 0  168456.0
#     item_id                  title                  genres
# 0  168456.0  Mercury Plains (2016)  Action|Adventure|Drama
#    item_id
# 0   1225.0
#    item_id           title genres
# 0   1225.0  Amadeus (1984)  Drama
#    item_id
# 0    379.0
#    item_id           title                  genres
# 0    379.0  Timecop (1994)  Action|Sci-Fi|Thriller
#    item_id
# 0    435.0
#    item_id             title         genres
# 0    435.0  Coneheads (1993)  Comedy|Sci-Fi
#    item_id
# 0   1213.0
#    item_id              title       genres
# 0   1213.0  Goodfellas (1990)  Crime|Drama
#    item_id
# 0  26375.0
#    item_id                 title               genres
# 0  26375.0  Silver Streak (1976)  Action|Comedy|Crime
#    item_id
# 0     95.0
#    item_id                title                     genres
# 0     95.0  Broken Arrow (1996)  Action|Adventure|Thriller
#    item_id
# 0   1213.0
#    item_id              title       genres
# 0   1213.0  Goodfellas (1990)  Crime|Drama
#    item_id
# 0    837.0
#    item_id           title                   genres
# 0    837.0  Matilda (1996)  Children|Comedy|Fantasy
#    item_id
# 0   5464.0
#    item_id                     title       genres
# 0   5464.0  Road to Perdition (2002)  Crime|Drama
#    item_id
# 0   3327.0
#    item_id                  title       genres
# 0   3327.0  Beyond the Mat (1999)  Documentary
#    item_id
# 0    750.0
#    item_id                                              title      genres
# 0    750.0  Dr. Strangelove or: How I Learned to Stop Worr...  Comedy|War
#    item_id
# 0    266.0
#    item_id                       title                     genres
# 0    266.0  Legends of the Fall (1994)  Drama|Romance|War|Western
#    item_id
# 0   3994.0
#    item_id               title        genres
# 0   3994.0  Unbreakable (2000)  Drama|Sci-Fi
#    item_id
# 0   2947.0
#    item_id              title                     genres
# 0   2947.0  Goldfinger (1964)  Action|Adventure|Thriller
#     item_id
# 0  158872.0
#     item_id                 title            genres
# 0  158872.0  Sausage Party (2016)  Animation|Comedy
#    item_id
# 0   3751.0
#    item_id               title                     genres
# 0   3751.0  Chicken Run (2000)  Animation|Children|Comedy
#    item_id
# 0   3551.0
#    item_id                title                genres
# 0   3551.0  Marathon Man (1976)  Crime|Drama|Thriller
#    item_id
# 0   6957.0
#    item_id             title        genres
# 0   6957.0  Bad Santa (2003)  Comedy|Crime
#    item_id
# 0    337.0
#    item_id                               title genres
# 0    337.0  What's Eating Gilbert Grape (1993)  Drama
#    item_id
# 0   3355.0
#    item_id                   title                           genres
# 0   3355.0  Ninth Gate, The (1999)  Fantasy|Horror|Mystery|Thriller
#    item_id
# 0   2463.0
#    item_id                   title  genres
# 0   2463.0  Ruthless People (1986)  Comedy
#     item_id
# 0  122892.0
#     item_id                           title                   genres
# 0  122892.0  Avengers: Age of Ultron (2015)  Action|Adventure|Sci-Fi
#    item_id
# 0    370.0
#    item_id                                      title         genres
# 0    370.0  Naked Gun 33 1/3: The Final Insult (1994)  Action|Comedy
#    item_id
# 0   3468.0
#    item_id                title genres
# 0   3468.0  Hustler, The (1961)  Drama
#    item_id
# 0     50.0
#    item_id                       title                  genres
# 0     50.0  Usual Suspects, The (1995)  Crime|Mystery|Thriller
#    item_id
# 0   1213.0
# ...
# 0  46578.0  Little Miss Sunshine (2006)  Adventure|Comedy|Drama
#    item_id
# 0   3089.0
#    item_id                                              title genres
# 0   3089.0  Bicycle Thieves (a.k.a. The Bicycle Thief) (a....  Drama
#    item_id
# 0  60684.0
#    item_id            title                                     genres
# 0  60684.0  Watchmen (2009)  Action|Drama|Mystery|Sci-Fi|Thriller|IMAX
#    item_id
# 0    858.0
#    item_id                  title       genres
# 0    858.0  Godfather, The (1972)  Crime|Drama
#    item_id
# 0   3468.0
#    item_id                title genres
# 0   3468.0  Hustler, The (1961)  Drama
#    item_id
# 0   2059.0
#    item_id                    title                   genres
# 0   2059.0  Parent Trap, The (1998)  Children|Comedy|Romance
#    item_id
# 0  60684.0
#    item_id            title                                     genres
# 0  60684.0  Watchmen (2009)  Action|Drama|Mystery|Sci-Fi|Thriller|IMAX
#    item_id
# 0    207.0
#    item_id                         title         genres
# 0    207.0  Walk in the Clouds, A (1995)  Drama|Romance
#    item_id
# 0   2100.0
#    item_id          title                  genres
# 0   2100.0  Splash (1984)  Comedy|Fantasy|Romance
#    item_id
# 0  39715.0
#    item_id                                              title  genres
# 0  39715.0  American Pie Presents: Band Camp (American Pie...  Comedy
#     item_id
# 0  119145.0
#     item_id                                title  \
# 0  119145.0  Kingsman: The Secret Service (2015)
#
#                           genres
# 0  Action|Adventure|Comedy|Crime
#     item_id
# 0  106072.0
#     item_id                        title                         genres
# 0  106072.0  Thor: The Dark World (2013)  Action|Adventure|Fantasy|IMAX
#    item_id
# 0  49274.0
#    item_id              title                                    genres
# 0  49274.0  Happy Feet (2006)  Adventure|Animation|Children|Comedy|IMAX
#    item_id
# 0   2692.0
#    item_id                             title        genres
# 0   2692.0  Run Lola Run (Lola rennt) (1998)  Action|Crime
#     item_id
# 0  131826.0
#     item_id                                  title  genres
# 0  131826.0  Iliza Shlesinger: Freezing Hot (2015)  Comedy
#    item_id
# 0    481.0
#    item_id              title          genres
# 0    481.0  Kalifornia (1993)  Drama|Thriller
#    item_id
# 0  48774.0
#    item_id                   title                                  genres
# 0  48774.0  Children of Men (2006)  Action|Adventure|Drama|Sci-Fi|Thriller
#    item_id
# 0   1500.0
#    item_id                       title                genres
# 0   1500.0  Grosse Pointe Blank (1997)  Comedy|Crime|Romance
#    item_id
# 0  27416.0
#    item_id                 title                genres
# 0  27416.0  Jalla! Jalla! (2000)  Comedy|Drama|Romance
#    item_id
# 0    813.0
#    item_id                    title  genres
# 0    813.0  Larger Than Life (1996)  Comedy
#    item_id
# 0   8340.0
#    item_id                        title          genres
# 0   8340.0  Escape from Alcatraz (1979)  Drama|Thriller
#    item_id
# 0  48774.0
#    item_id                   title                                  genres
# 0  48774.0  Children of Men (2006)  Action|Adventure|Drama|Sci-Fi|Thriller
#    item_id
# 0    543.0
#    item_id                                title                   genres
# 0    543.0  So I Married an Axe Murderer (1993)  Comedy|Romance|Thriller
#     item_id
# 0  126548.0
#     item_id            title  genres
# 0  126548.0  The DUFF (2015)  Comedy
#    item_id
# 0    858.0
#    item_id                  title       genres
# 0    858.0  Godfather, The (1972)  Crime|Drama
#    item_id
# 0   2313.0
#    item_id                     title genres
# 0   2313.0  Elephant Man, The (1980)  Drama
#    item_id
# 0   7482.0
#    item_id                    title        genres
# 0   7482.0  Enter the Dragon (1973)  Action|Crime
#    item_id
# 0   5103.0
#    item_id                title                 genres
# 0   5103.0  Sandlot, The (1993)  Children|Comedy|Drama
#    item_id
# 0   8798.0
#    item_id              title                       genres
# 0   8798.0  Collateral (2004)  Action|Crime|Drama|Thriller
#    item_id
# 0   1185.0
#    item_id                title genres
# 0   1185.0  My Left Foot (1989)  Drama
#    item_id
# 0  30822.0
#    item_id                   title        genres
# 0  30822.0  In Good Company (2004)  Comedy|Drama
#    item_id
# 0   2986.0
#    item_id             title                        genres
# 0   2986.0  RoboCop 2 (1990)  Action|Crime|Sci-Fi|Thriller
#    item_id
# 0   3219.0
#    item_id                   title            genres
# 0   3219.0  Pacific Heights (1990)  Mystery|Thriller
#    item_id
# 0  46578.0
#    item_id                        title                  genres
# 0  46578.0  Little Miss Sunshine (2006)  Adventure|Comedy|Drama
#    item_id
# 0  83349.0
#    item_id                     title  \
# 0  83349.0  Green Hornet, The (2011)
#
#                                       genres
# 0  Action|Comedy|Crime|Fantasy|Thriller|IMAX
#    item_id
# 0   1500.0
#    item_id                       title                genres
# 0   1500.0  Grosse Pointe Blank (1997)  Comedy|Crime|Romance
#    item_id
# 0   2502.0
#    item_id                title        genres
# 0   2502.0  Office Space (1999)  Comedy|Crime
#     item_id
# 0  168252.0
#     item_id         title         genres
# 0  168252.0  Logan (2017)  Action|Sci-Fi
#     item_id
# 0  139747.0
#     item_id                title   genres
# 0  139747.0  Before We Go (2014)  Romance
#    item_id
# 0   1964.0
#    item_id         title         genres
# 0   1964.0  Klute (1971)  Drama|Mystery
#    item_id
# 0   4890.0
#    item_id               title                  genres
# 0   4890.0  Shallow Hal (2001)  Comedy|Fantasy|Romance
#    item_id
# 0   1203.0
#    item_id                title genres
# 0   1203.0  12 Angry Men (1957)  Drama
#    item_id
# 0   2947.0
#    item_id              title                     genres
# 0   2947.0  Goldfinger (1964)  Action|Adventure|Thriller
#    item_id
# 0     50.0
#    item_id                       title                  genres
# 0     50.0  Usual Suspects, The (1995)  Crime|Mystery|Thriller
#    item_id
# 0  98122.0
#    item_id                         title       genres
# 0  98122.0  Indie Game: The Movie (2012)  Documentary
#    item_id
# 0   2301.0
#    item_id                                title          genres
# 0   2301.0  History of the World: Part I (1981)  Comedy|Musical
#    item_id
# 0   2145.0
#    item_id                  title                genres
# 0   2145.0  Pretty in Pink (1986)  Comedy|Drama|Romance
#    item_id
# 0    145.0
#    item_id            title                              genres
# 0    145.0  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller
#    item_id
# 0    809.0
#    item_id        title            genres
# 0    809.0  Fled (1996)  Action|Adventure
#    item_id
# 0   2000.0
#    item_id                 title                     genres
# 0   2000.0  Lethal Weapon (1987)  Action|Comedy|Crime|Drama
#    item_id
# 0   2690.0
#    item_id                     title          genres
# 0   2690.0  Ideal Husband, An (1999)  Comedy|Romance
#    item_id
# 0   1079.0
#    item_id                        title        genres
# 0   1079.0  Fish Called Wanda, A (1988)  Comedy|Crime
#    item_id
# 0   2396.0
#    item_id                       title                genres
# 0   2396.0  Shakespeare in Love (1998)  Comedy|Drama|Romance
#    item_id
# 0   1213.0
#    item_id              title       genres
# 0   1213.0  Goodfellas (1990)  Crime|Drama
#    item_id
# 0   1079.0
#    item_id                        title        genres
# 0   1079.0  Fish Called Wanda, A (1988)  Comedy|Crime
#    item_id
# 0   2311.0
#    item_id                                  title  genres
# 0   2311.0  2010: The Year We Make Contact (1984)  Sci-Fi
#    item_id
# 0    780.0
#    item_id                                 title  \
# 0    780.0  Independence Day (a.k.a. ID4) (1996)
#
#                              genres
# 0  Action|Adventure|Sci-Fi|Thriller
#    item_id
# 0   3751.0
#    item_id               title                     genres
# 0   3751.0  Chicken Run (2000)  Animation|Children|Comedy
#    item_id
# 0   4796.0
#    item_id                         title          genres
# 0   4796.0  Grass Is Greener, The (1960)  Comedy|Romance
#    item_id
# 0    170.0
#    item_id           title                           genres
# 0    170.0  Hackers (1995)  Action|Adventure|Crime|Thriller
#    item_id
# 0   1704.0
#    item_id                     title         genres
# 0   1704.0  Good Will Hunting (1997)  Drama|Romance
#    item_id
# 0   3159.0
#    item_id                 title                           genres
# 0   3159.0  Fantasia 2000 (1999)  Animation|Children|Musical|IMAX
#    item_id
# 0   3668.0
#    item_id                    title         genres
# 0   3668.0  Romeo and Juliet (1968)  Drama|Romance
#    item_id
# 0  64957.0
#    item_id                                        title  \
# 0  64957.0  Curious Case of Benjamin Button, The (2008)
#
#                           genres
# 0  Drama|Fantasy|Mystery|Romance
#    item_id
# 0  70545.0
#    item_id             title  genres
# 0  70545.0  Deal, The (2008)  Comedy
#    item_id
# 0  70946.0
#    item_id           title          genres
# 0  70946.0  Troll 2 (1990)  Fantasy|Horror
#    item_id
# 0   6187.0
#    item_id                           title                genres
# 0   6187.0  Life of David Gale, The (2003)  Crime|Drama|Thriller
#    item_id
# 0   1704.0
#    item_id                     title         genres
# 0   1704.0  Good Will Hunting (1997)  Drama|Romance
#    item_id
# 0   4890.0
#    item_id               title                  genres
# 0   4890.0  Shallow Hal (2001)  Comedy|Fantasy|Romance
#    item_id
# 0   2671.0
#    item_id                title          genres
# 0   2671.0  Notting Hill (1999)  Comedy|Romance
#    item_id
# 0   3159.0
#    item_id                 title                           genres
# 0   3159.0  Fantasia 2000 (1999)  Animation|Children|Musical|IMAX
#    item_id
# 0    435.0
#    item_id             title         genres
# 0    435.0  Coneheads (1993)  Comedy|Sci-Fi
#    item_id
# 0  67734.0
#    item_id                 title        genres
# 0  67734.0  Adventureland (2009)  Comedy|Drama
#    item_id
# 0   2972.0
#    item_id                                title     genres
# 0   2972.0  Red Sorghum (Hong gao liang) (1987)  Drama|War
#    item_id
# 0    586.0
#    item_id              title           genres
# 0    586.0  Home Alone (1990)  Children|Comedy
#    item_id
# 0   1079.0
#    item_id                        title        genres
# 0   1079.0  Fish Called Wanda, A (1988)  Comedy|Crime
#    item_id
# 0  46578.0
#    item_id                        title                  genres
# 0  46578.0  Little Miss Sunshine (2006)  Adventure|Comedy|Drama
#    item_id
# 0   2671.0
#    item_id                title          genres
# 0   2671.0  Notting Hill (1999)  Comedy|Romance
#    item_id
# 0  64957.0
#    item_id                                        title  \
# 0  64957.0  Curious Case of Benjamin Button, The (2008)
#
#                           genres
# 0  Drama|Fantasy|Mystery|Romance
#    item_id
# 0    435.0
#    item_id             title         genres
# 0    435.0  Coneheads (1993)  Comedy|Sci-Fi
#    item_id
# 0   4890.0
#    item_id               title                  genres
# 0   4890.0  Shallow Hal (2001)  Comedy|Fantasy|Romance
#    item_id
# 0   3507.0
#    item_id                   title  genres
# 0   3507.0  Odd Couple, The (1968)  Comedy
#    item_id
# 0    780.0
#    item_id                                 title  \
# 0    780.0  Independence Day (a.k.a. ID4) (1996)
#
#                              genres
# 0  Action|Adventure|Sci-Fi|Thriller
#    item_id
# 0   3986.0
#    item_id                title                  genres
# 0   3986.0  6th Day, The (2000)  Action|Sci-Fi|Thriller
#     item_id
# 0  119145.0
#     item_id                                title  \
# 0  119145.0  Kingsman: The Secret Service (2015)
#
#                           genres
# 0  Action|Adventure|Comedy|Crime
#    item_id
# 0    586.0
#    item_id              title           genres
# 0    586.0  Home Alone (1990)  Children|Comedy
#    item_id
# 0   8366.0
#    item_id          title        genres
# 0   8366.0  Saved! (2004)  Comedy|Drama
#    item_id
# 0   1225.0
#    item_id           title genres
# 0   1225.0  Amadeus (1984)  Drama
#    item_id
# 0   3006.0
#    item_id                title          genres
# 0   3006.0  Insider, The (1999)  Drama|Thriller
#    item_id
# 0    788.0
#    item_id                        title                         genres
# 0    788.0  Nutty Professor, The (1996)  Comedy|Fantasy|Romance|Sci-Fi
#    item_id
# 0   6881.0
#    item_id                   title        genres
# 0   6881.0  Pieces of April (2003)  Comedy|Drama
#    item_id
# 0   3994.0
#    item_id               title        genres
# 0   3994.0  Unbreakable (2000)  Drama|Sci-Fi
#    item_id
# 0  41566.0
#    item_id                                              title  \
# 0  41566.0  Chronicles of Narnia: The Lion, the Witch and ...
#
#                        genres
# 0  Adventure|Children|Fantasy
#    item_id
# 0   6755.0
#    item_id                title         genres
# 0   6755.0  Bubba Ho-tep (2002)  Comedy|Horror
#    item_id
# 0   1021.0
#    item_id                          title           genres
# 0   1021.0  Angels in the Outfield (1994)  Children|Comedy
#    item_id
# 0  83349.0
#    item_id                     title  \
# 0  83349.0  Green Hornet, The (2011)
#
#                                       genres
# 0  Action|Comedy|Crime|Fantasy|Thriller|IMAX
#    item_id
# 0  64957.0
#    item_id                                        title  \
# 0  64957.0  Curious Case of Benjamin Button, The (2008)
#
#                           genres
# 0  Drama|Fantasy|Mystery|Romance
#    item_id
# 0   4239.0
#    item_id        title       genres
# 0   4239.0  Blow (2001)  Crime|Drama
#    item_id
# 0   1704.0
#    item_id                     title         genres
# 0   1704.0  Good Will Hunting (1997)  Drama|Romance
#    item_id
# 0   4896.0
#    item_id                                              title  \
# 0   4896.0  Harry Potter and the Sorcerer's Stone (a.k.a. ...
#
#                        genres
# 0  Adventure|Children|Fantasy
#    item_id
# 0    930.0
#    item_id             title                      genres
# 0    930.0  Notorious (1946)  Film-Noir|Romance|Thriller
#    item_id
# 0   2010.0
#    item_id              title        genres
# 0   2010.0  Metropolis (1927)  Drama|Sci-Fi
#    item_id
# 0   3635.0
#    item_id                         title                     genres
# 0   3635.0  Spy Who Loved Me, The (1977)  Action|Adventure|Thriller
#    item_id
# 0    274.0
#    item_id                    title  genres
# 0    274.0  Man of the House (1995)  Comedy
#     item_id
# 0  111146.0
#     item_id                                           title  \
# 0  111146.0  Alpha and Omega 3: The Great Wolf Games (2014)
#
#                                        genres
# 0  Action|Adventure|Animation|Children|Comedy
#    item_id
# 0   4464.0
#    item_id                           title                genres
# 0   4464.0  Accidental Tourist, The (1988)  Comedy|Drama|Romance
#     item_id
# 0  146684.0
#     item_id                          title                     genres
# 0  146684.0  Cosmic Scrat-tastrophe (2015)  Animation|Children|Comedy
#    item_id
# 0   2108.0
#    item_id              title          genres
# 0   2108.0  L.A. Story (1991)  Comedy|Romance
#     item_id
# 0  132796.0
#     item_id               title                 genres
# 0  132796.0  San Andreas (2015)  Action|Drama|Thriller
#    item_id
# 0  41566.0
#    item_id                                              title  \
# 0  41566.0  Chronicles of Narnia: The Lion, the Witch and ...
#
#                        genres
# 0  Adventure|Children|Fantasy
#    item_id
# 0   2677.0
#    item_id                           title               genres
# 0   2677.0  Buena Vista Social Club (1999)  Documentary|Musical
#    item_id
# 0   3062.0
#    item_id                    title            genres
# 0   3062.0  Longest Day, The (1962)  Action|Drama|War
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>RMSE</th>
#       <th>MRE</th>
#       <th>TRE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BaseRecommender</td>
#       <td>1.170155</td>
#       <td>0.349264</td>
#       <td>0.271796</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Implicit feedback

# %% [markdown]
# **Task 1.** Implement the following method for train-test split evaluation for implicit feedback.

# %%
def evaluate_train_test_split_implicit(recommender, interactions_df, items_df, seed=6789):
    rng = np.random.RandomState(seed=seed)
    # Split the dataset into train and test
    shuffle = np.arange(len(interactions_df))
    rng.shuffle(shuffle)
    shuffle = list(shuffle)
    train_test_split = 0.8
    split_index = int(len(interactions_df) * train_test_split)
    interactions_df_train = interactions_df.iloc[shuffle[:split_index]]
    interactions_df_test = interactions_df.iloc[shuffle[split_index:]]
    # Train the recommender
    
    recommender.fit(interactions_df_train, None, items_df)
    
    
    hr_1 = []
    hr_3 = []
    hr_5 = []
    hr_10 = []
    
    users_ids = interactions_df_test.loc[:, ['user_id']].drop_duplicates(subset='user_id')
    recommendations = recommender.recommend(users_ids, items_df, n_recommendations=10)
#     display(HTML(recommendations.to_html()))
    hr_1.append(hr(recommendations, interactions_df_test, n=1))
    hr_3.append(hr(recommendations, interactions_df_test, n=3))
    hr_5.append(hr(recommendations, interactions_df_test, n=5))
    hr_10.append(hr(recommendations, interactions_df_test, n=10))
    
    hr_1 = np.mean(hr_1)
    hr_3 = np.mean(hr_3)
    hr_5 = np.mean(hr_5)
    hr_10 = np.mean(hr_10)
    
    return hr_1, hr_3, hr_5, hr_10

recommender = TFIDFRecommender()

results = [['BaseRecommender'] + list(evaluate_train_test_split_implicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id']], ml_movies_df))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10'])

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>HR@1</th>
#       <th>HR@3</th>
#       <th>HR@5</th>
#       <th>HR@10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BaseRecommender</td>
#       <td>0.017897</td>
#       <td>0.044743</td>
#       <td>0.058166</td>
#       <td>0.09396</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Leave-one-out, leave-k-out, cross-validation

# %% [markdown]
# ### Explicit feedback

# %% [markdown]
# **Task 2.** Implement the following method for leave-one-out evaluation for explicit feedback.

# %%
def evaluate_leave_one_out_explicit(recommender, interactions_df, items_df, max_evals=300, seed=6789):
    rng = np.random.RandomState(seed=seed)
    
    # Prepare splits of the datasets
    kf = KFold(n_splits=len(interactions_df), random_state=rng, shuffle=True)
    

    # For each split of the dataset train the recommender, generate recommendations and evaluate
    r_pred = []
    r_real = []
    n_eval = 1
    for train_index, test_index in kf.split(interactions_df.index):
        interactions_df_train = interactions_df.loc[interactions_df.index[train_index]]
        interactions_df_test = interactions_df.loc[interactions_df.index[test_index]]
                
        recommender.fit(interactions_df_train, None, items_df)
        item = interactions_df_test.loc[:, ['item_id']]
        item = pd.merge(item, items_df, on='item_id')
        recommendations = recommender.recommend(interactions_df_test.loc[:, ['user_id']], 
                                                item, 
                                                n_recommendations=1)
        
        r_pred.append(recommendations.iloc[0]['score'])
        r_real.append(interactions_df_test['rating'].tolist()[0])
        if n_eval == max_evals:
            break
        n_eval += 1
    
    r_real = np.array(r_real)
#     print(r_pred)
#     print(r_real)
    return rmse(r_pred, r_real), mre(r_pred, r_real), tre(r_pred, r_real)

recommender = LinearRegressionRecommender()
results = [['BaseRecommender'] + list(evaluate_leave_one_out_explicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], ml_movies_df))]
results = pd.DataFrame(results, 
                       columns=['Recommender', 'RMSE', 'MRE', 'TRE'])
display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>RMSE</th>
#       <th>MRE</th>
#       <th>TRE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BaseRecommender</td>
#       <td>1.039763</td>
#       <td>0.401878</td>
#       <td>0.240408</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Implicit feedback

# %% [markdown]
# # Linear Regression Recommender
#
# For every movie we transform its genres into one-hot encoded features and then fit a linear regression model to those features and actual ratings.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MultiLabelBinarizer

class LinearRegressionRecommender(object):
    """
    Base recommender class.
    """
    
    def __init__(self):
        """
        Initialize base recommender params and variables.
        """
        self.model = None
        self.mlb = None
    
    def fit(self, interactions_df, users_df, items_df):
        """
        Training of the recommender.
        
        :param pd.DataFrame interactions_df: DataFrame with recorded interactions between users and items 
            defined by user_id, item_id and features of the interaction.
        :param pd.DataFrame users_df: DataFrame with users and their features defined by user_id and the user feature columns.
        :param pd.DataFrame items_df: DataFrame with items and their features defined by item_id and the item feature columns.
        """
        
        interactions_df = pd.merge(interactions_df, items_df, on='item_id')
        interactions_df.loc[:, 'genres'] = interactions_df['genres'].str.replace("-", "_", regex=False)
        interactions_df.loc[:, 'genres'] = interactions_df['genres'].str.replace(" ", "_", regex=False)
        interactions_df.loc[:, 'genres'] = interactions_df['genres'].str.lower()
        interactions_df.loc[:, 'genres'] = interactions_df['genres'].str.split("|")
        
        self.mlb = MultiLabelBinarizer()
        interactions_df = interactions_df.join(
            pd.DataFrame(self.mlb.fit_transform(interactions_df.pop('genres')),
                         columns=self.mlb.classes_,
                         index=interactions_df.index))
        
#         print(interactions_df.head())
        
        x = interactions_df.loc[:, self.mlb.classes_].values
        y = interactions_df['rating'].values
    
        self.model = LinearRegression().fit(x, y)
    
    def recommend(self, users_df, items_df, n_recommendations=1):
        """
        Serving of recommendations. Scores items in items_df for each user in users_df and returns 
        top n_recommendations for each user.
        
        :param pd.DataFrame users_df: DataFrame with users and their features for which recommendations should be generated.
        :param pd.DataFrame items_df: DataFrame with items and their features which should be scored.
        :param int n_recommendations: Number of recommendations to be returned for each user.
        :return: DataFrame with user_id, item_id and score as columns returning n_recommendations top recommendations 
            for each user.
        :rtype: pd.DataFrame
        """
        
        # Transform the item to be scored into proper features
        
        items_df = items_df.copy()
        items_df.loc[:, 'genres'] = items_df['genres'].str.replace("-", "_", regex=False)
        items_df.loc[:, 'genres'] = items_df['genres'].str.replace(" ", "_", regex=False)
        items_df.loc[:, 'genres'] = items_df['genres'].str.lower()
        items_df.loc[:, 'genres'] = items_df['genres'].str.split("|")
        
        items_df = items_df.join(
            pd.DataFrame(self.mlb.transform(items_df.pop('genres')),
                         columns=self.mlb.classes_,
                         index=items_df.index))
        
#         print(items_df)
        
        # Score the item
    
        recommendations = pd.DataFrame(columns=['user_id', 'item_id', 'score'])
        
        for ix, user in users_df.iterrows():
            score = self.model.predict(items_df.loc[:, self.mlb.classes_].values)[0]
                
            user_recommendations = pd.DataFrame({'user_id': [user['user_id']],
                                                 'item_id': items_df.iloc[0]['item_id'],
                                                 'score': score})

            recommendations = pd.concat([recommendations, user_recommendations])

        return recommendations

# %%
# Quick test of the recommender

lr_recommender = LinearRegressionRecommender()
lr_recommender.fit(ml_ratings_df, None, ml_movies_df)
recommendations = lr_recommender.recommend(pd.DataFrame([[1], [2]], columns=['user_id']), ml_movies_df, 1)

recommendations = pd.merge(recommendations, ml_movies_df, on='item_id')
display(HTML(recommendations.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>item_id</th>
#       <th>score</th>
#       <th>title</th>
#       <th>genres</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>145</td>
#       <td>3.282778</td>
#       <td>Bad Boys (1995)</td>
#       <td>Action|Comedy|Crime|Drama|Thriller</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>145</td>
#       <td>3.282778</td>
#       <td>Bad Boys (1995)</td>
#       <td>Action|Comedy|Crime|Drama|Thriller</td>
#     </tr>
#   </tbody>
# </table>

# %%
lr_recommender = LinearRegressionRecommender()

results = [['LinearRegressionRecommender'] + list(evaluate_train_test_split_explicit(
    lr_recommender, ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], ml_movies_df, seed=6789))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'RMSE', 'MRE', 'TRE'])

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>RMSE</th>
#       <th>MRE</th>
#       <th>TRE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>LinearRegressionRecommender</td>
#       <td>1.019263</td>
#       <td>0.370077</td>
#       <td>0.245447</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # TF-IDF Recommender
# TF-IDF stands for term frequency–inverse document frequency. Typically Tf-IDF method is used to assign keywords (words describing the gist of a document) to documents in a corpus of documents.
#
# In our case we will treat users as documents and genres as words.
#
# Term-frequency is given by the following formula:
# <center>
# $$
#     \text{tf}(g, u) = f_{g, u}
# $$
# </center>
# where $f_{g, i}$ is the number of times genre $g$ appear for movies watched by user $u$.
#
# Inverse document frequency is defined as follows:
# <center>
# $$
#     \text{idf}(g) = \log \frac{N}{n_g}
# $$
# </center>
# where $N$ is the number of users and $n_g$ is the number of users with $g$ in their genres list.
#
# Finally, tf-idf is defined as follows:
# <center>
# $$
#     \text{tfidf}(g, u) = \text{tf}(g, u) \cdot \text{idf}(g)
# $$
# </center>
#
# In our case we will measure how often a given genre appears for movies watched by a given user vs how often it appears for all users. To obtain a movie score we will take the average of its genres' scores for this user.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

class TFIDFRecommender(object):
    """
    Recommender based on the TF-IDF method.
    """
    
    def __init__(self):
        """
        Initialize base recommender params and variables.
        """
        self.tfidf_scores = None
    
    def fit(self, interactions_df, users_df, items_df):
        """
        Training of the recommender.
        
        :param pd.DataFrame interactions_df: DataFrame with recorded interactions between users and items 
            defined by user_id, item_id and features of the interaction.
        :param pd.DataFrame users_df: DataFrame with users and their features defined by user_id and the user feature columns.
        :param pd.DataFrame items_df: DataFrame with items and their features defined by item_id and the item feature columns.
        """
        
        self.tfidf_scores = defaultdict(lambda: 0.0)

        # Prepare the corpus for tfidf calculation
        
        interactions_df = pd.merge(interactions_df, items_df, on='item_id')
        user_genres = interactions_df.loc[:, ['user_id', 'genres']]
        user_genres.loc[:, 'genres'] = user_genres['genres'].str.replace("-", "_", regex=False)
        user_genres.loc[:, 'genres'] = user_genres['genres'].str.replace(" ", "_", regex=False)
        user_genres = user_genres.groupby('user_id').aggregate(lambda x: "|".join(x))
        user_genres.loc[:, 'genres'] = user_genres['genres'].str.replace("|", " ", regex=False)
#         print(user_genres)
        user_ids = user_genres.index.tolist()
        genres_corpus = user_genres['genres'].tolist()
        
        # Calculate tf-idf scores
        
        vectorizer = TfidfVectorizer()
        tfidf_scores = vectorizer.fit_transform(genres_corpus)
        
        # Transform results into a dict {(user_id, genre): score}
        
        for u in range(tfidf_scores.shape[0]):
            for g in range(tfidf_scores.shape[1]):
                self.tfidf_scores[(user_ids[u], vectorizer.get_feature_names()[g])] = tfidf_scores[u, g]
                
#         print(self.tfidf_scores)
    
    def recommend(self, users_df, items_df, n_recommendations=1):
        """
        Serving of recommendations. Scores items in items_df for each user in users_df and returns 
        top n_recommendations for each user.
        
        :param pd.DataFrame users_df: DataFrame with users and their features for which recommendations should be generated.
        :param pd.DataFrame items_df: DataFrame with items and their features which should be scored.
        :param int n_recommendations: Number of recommendations to be returned for each user.
        :return: DataFrame with user_id, item_id and score as columns returning n_recommendations top recommendations 
            for each user.
        :rtype: pd.DataFrame
        """
        
        recommendations = pd.DataFrame(columns=['user_id', 'item_id', 'score'])
        
        # Transform genres to a unified form used by the vectorizer
        
        items_df = items_df.copy()
        items_df.loc[:, 'genres'] = items_df['genres'].str.replace("-", "_", regex=False)
        items_df.loc[:, 'genres'] = items_df['genres'].str.replace(" ", "_", regex=False)
        items_df.loc[:, 'genres'] = items_df['genres'].str.lower()
        items_df.loc[:, 'genres'] = items_df['genres'].str.split("|")
                
        # Score items    
        
        for uix, user in users_df.iterrows():
            items = []
            for iix, item in items_df.iterrows():
                score = 0.0
                for genre in item['genres']:
                    score += self.tfidf_scores[(user['user_id'], genre)]
                score /= len(item['genres'])
                items.append((item['item_id'], score))
                
            items = sorted(items, key=lambda x: x[1], reverse=True)
            user_recommendations = pd.DataFrame({'user_id': user['user_id'],
                                                 'item_id': [item[0] for item in items][:n_recommendations],
                                                 'score': [item[1] for item in items][:n_recommendations]})

            recommendations = pd.concat([recommendations, user_recommendations])

        return recommendations

# %%
# Quick test of the recommender

tfidf_recommender = TFIDFRecommender()
tfidf_recommender.fit(ml_ratings_df, None, ml_movies_df)
recommendations = tfidf_recommender.recommend(pd.DataFrame([[1], [2]], columns=['user_id']), ml_movies_df, 3)

recommendations = pd.merge(recommendations, ml_movies_df, on='item_id')
display(HTML(recommendations.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>item_id</th>
#       <th>score</th>
#       <th>title</th>
#       <th>genres</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2690</td>
#       <td>0.452122</td>
#       <td>Ideal Husband, An (1999)</td>
#       <td>Comedy|Romance</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>3614</td>
#       <td>0.452122</td>
#       <td>Honeymoon in Vegas (1992)</td>
#       <td>Comedy|Romance</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>4796</td>
#       <td>0.452122</td>
#       <td>Grass Is Greener, The (1960)</td>
#       <td>Comedy|Romance</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>145</td>
#       <td>0.000000</td>
#       <td>Bad Boys (1995)</td>
#       <td>Action|Comedy|Crime|Drama|Thriller</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>171</td>
#       <td>0.000000</td>
#       <td>Jeffrey (1995)</td>
#       <td>Comedy|Drama</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>228</td>
#       <td>0.000000</td>
#       <td>Destiny Turns on the Radio (1995)</td>
#       <td>Comedy</td>
#     </tr>
#   </tbody>
# </table>

# %%
tfidf_recommender = TFIDFRecommender()

results = [['TFIDFRecommender'] + list(evaluate_leave_one_out_implicit(
    tfidf_recommender, ml_ratings_df.loc[:, ['user_id', 'item_id']], ml_movies_df, max_evals=300, seed=6789))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>HR@1</th>
#       <th>HR@3</th>
#       <th>HR@5</th>
#       <th>HR@10</th>
#       <th>NDCG@1</th>
#       <th>NDCG@3</th>
#       <th>NDCG@5</th>
#       <th>NDCG@10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>TFIDFRecommender</td>
#       <td>0.006667</td>
#       <td>0.053333</td>
#       <td>0.123333</td>
#       <td>0.233333</td>
#       <td>0.006667</td>
#       <td>0.033491</td>
#       <td>0.062178</td>
#       <td>0.096151</td>
#     </tr>
#   </tbody>
# </table>

# %%
def evaluate_leave_one_out_implicit(recommender, interactions_df, items_df, max_evals=300, seed=6789):
    rng = np.random.RandomState(seed=seed)
    
    # Prepare splits of the datasets
    kf = KFold(n_splits=len(interactions_df), random_state=rng, shuffle=True)
    
    hr_1 = []
    hr_3 = []
    hr_5 = []
    hr_10 = []
    ndcg_1 = []
    ndcg_3 = []
    ndcg_5 = []
    ndcg_10 = []
    
    # For each split of the dataset train the recommender, generate recommendations and evaluate
    
    n_eval = 1
    for train_index, test_index in kf.split(interactions_df.index):
        interactions_df_train = interactions_df.loc[interactions_df.index[train_index]]
        interactions_df_test = interactions_df.loc[interactions_df.index[test_index]]
                
        recommender.fit(interactions_df_train, None, items_df)
        recommendations = recommender.recommend(interactions_df_test.loc[:, ['user_id']], items_df, n_recommendations=10)
        
        hr_1.append(hr(recommendations, interactions_df_test, n=1))
        hr_3.append(hr(recommendations, interactions_df_test, n=3))
        hr_5.append(hr(recommendations, interactions_df_test, n=5))
        hr_10.append(hr(recommendations, interactions_df_test, n=10))
        ndcg_1.append(ndcg(recommendations, interactions_df_test, n=1))
        ndcg_3.append(ndcg(recommendations, interactions_df_test, n=3))
        ndcg_5.append(ndcg(recommendations, interactions_df_test, n=5))
        ndcg_10.append(ndcg(recommendations, interactions_df_test, n=10))
        
        if n_eval == max_evals:
            break
        n_eval += 1
        
    hr_1 = np.mean(hr_1)
    hr_3 = np.mean(hr_3)
    hr_5 = np.mean(hr_5)
    hr_10 = np.mean(hr_10)
    ndcg_1 = np.mean(ndcg_1)
    ndcg_3 = np.mean(ndcg_3)
    ndcg_5 = np.mean(ndcg_5)
    ndcg_10 = np.mean(ndcg_10)
    
    return hr_1, hr_3, hr_5, hr_10, ndcg_1, ndcg_3, ndcg_5, ndcg_10

# recommender = TFIDFRecommender()

# results = [['BaseRecommender'] + list(evaluate_leave_one_out_implicit(
#     recommender, ml_ratings_df.loc[:, ['user_id', 'item_id']], ml_movies_df))]

# results = pd.DataFrame(results, 
#                        columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])

# display(HTML(results.to_html()))

recommender = MostPopularRecommender()
results = [['MostPopularRecommender'] + list(evaluate_leave_one_out_implicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id']], ml_movies_df))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>HR@1</th>
#       <th>HR@3</th>
#       <th>HR@5</th>
#       <th>HR@10</th>
#       <th>NDCG@1</th>
#       <th>NDCG@3</th>
#       <th>NDCG@5</th>
#       <th>NDCG@10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>MostPopularRecommender</td>
#       <td>0.026667</td>
#       <td>0.05</td>
#       <td>0.083333</td>
#       <td>0.163333</td>
#       <td>0.026667</td>
#       <td>0.040079</td>
#       <td>0.053997</td>
#       <td>0.079749</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Tasks

# %% [markdown]
# **Task 3.** Implement the MostPopularRecommender (check the slides for class 1), evaluate it with leave-one-out procedure for implicit feedback, print HR@1, HR@3, HR@5, HR@10, NDCG@1, NDCG@3, NDCG@5, NDCG@10.

# %%
class MostPopularRecommender(object):
    """
    Most popular recommender class.
    """
    
    def __init__(self):
        """
        Initialize base recommender params and variables.
        """
        self.most_popular = []
        pass
    
    def fit(self, interactions_df, users_df, items_df):
        """
        Training of the recommender.
        
        :param pd.DataFrame interactions_df: DataFrame with recorded interactions between users and items 
            defined by user_id, item_id and features of the interaction.
        :param pd.DataFrame users_df: DataFrame with users and their features defined by user_id and the user feature columns.
        :param pd.DataFrame items_df: DataFrame with items and their features defined by item_id and the item feature columns.
        """
        grouped = interactions_df.groupby('item_id').size().reset_index(name='counts').sort_values(by=['counts'], ascending=False)
#         grouped = interactions_df.groupby('item_id').count().sort_values(by=['user_id'], ascending=False)
        self.most_popular = list(grouped['item_id'])
    
    def recommend(self, users_df, items_df, n_recommendations=1):
        """
        Serving of recommendations. Scores items in items_df for each user in users_df and returns 
        top n_recommendations for each user.
        
        :param pd.DataFrame users_df: DataFrame with users and their features for which recommendations should be generated.
        :param pd.DataFrame items_df: DataFrame with items and their features which should be scored.
        :param int n_recommendations: Number of recommendations to be returned for each user.
        :return: DataFrame with user_id, item_id and score as columns returning n_recommendations top recommendations 
            for each user.
        :rtype: pd.DataFrame
        """
        
        recommendations = pd.DataFrame(columns=['user_id', 'item_id', 'score'])
        
        for ix, user in users_df.iterrows():
            user_recommendations = pd.DataFrame({'user_id': user['user_id'],
                                                 'item_id': self.most_popular[:n_recommendations],
                                                 'score': [3.0] * n_recommendations})

            recommendations = pd.concat([recommendations, user_recommendations])

        return recommendations

recommender = MostPopularRecommender()
results = [['MostPopularRecommender'] + list(evaluate_leave_one_out_implicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id']], ml_movies_df, max_evals=300, seed=6789))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>HR@1</th>
#       <th>HR@3</th>
#       <th>HR@5</th>
#       <th>HR@10</th>
#       <th>NDCG@1</th>
#       <th>NDCG@3</th>
#       <th>NDCG@5</th>
#       <th>NDCG@10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>MostPopularRecommender</td>
#       <td>0.026667</td>
#       <td>0.05</td>
#       <td>0.083333</td>
#       <td>0.163333</td>
#       <td>0.026667</td>
#       <td>0.040079</td>
#       <td>0.053997</td>
#       <td>0.079749</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Task 4.** Implement the HighestRatedRecommender (check the slides for class 1), evaluate it with leave-one-out procedure for implicit feedback, print HR@1, HR@3, HR@5, HR@10, NDCG@1, NDCG@3, NDCG@5, NDCG@10.

# %%
class HighestRatedRecommender(object):
    """
    Highest rated recommender class.
    """
    
    def __init__(self):
        """
        Initialize base recommender params and variables.
        """
        self.highest_rated = []
        pass
    
    def fit(self, interactions_df, users_df, items_df):
        """
        Training of the recommender.
        
        :param pd.DataFrame interactions_df: DataFrame with recorded interactions between users and items 
            defined by user_id, item_id and features of the interaction.
        :param pd.DataFrame users_df: DataFrame with users and their features defined by user_id and the user feature columns.
        :param pd.DataFrame items_df: DataFrame with items and their features defined by item_id and the item feature columns.
        """
        grouped = interactions_df.drop(columns=['user_id']).groupby('item_id').mean('rating').sort_values(by=['rating', 'item_id'], ascending=[False, True])
        self.highest_rated = list(grouped.index)
    
    def recommend(self, users_df, items_df, n_recommendations=1):
        """
        Serving of recommendations. Scores items in items_df for each user in users_df and returns 
        top n_recommendations for each user.
        
        :param pd.DataFrame users_df: DataFrame with users and their features for which recommendations should be generated.
        :param pd.DataFrame items_df: DataFrame with items and their features which should be scored.
        :param int n_recommendations: Number of recommendations to be returned for each user.
        :return: DataFrame with user_id, item_id and score as columns returning n_recommendations top recommendations 
            for each user.
        :rtype: pd.DataFrame
        """
        
        recommendations = pd.DataFrame(columns=['user_id', 'item_id', 'score'])
        
        for ix, user in users_df.iterrows():
            user_recommendations = pd.DataFrame({'user_id': user['user_id'],
                                                 'item_id': self.highest_rated[:n_recommendations],
                                                 'score': [3.0] * n_recommendations})

            recommendations = pd.concat([recommendations, user_recommendations])

        return recommendations

recommender = HighestRatedRecommender()
results = [['HighestRatedRecommender'] + list(evaluate_leave_one_out_implicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], ml_movies_df, max_evals=300, seed=6789))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>HR@1</th>
#       <th>HR@3</th>
#       <th>HR@5</th>
#       <th>HR@10</th>
#       <th>NDCG@1</th>
#       <th>NDCG@3</th>
#       <th>NDCG@5</th>
#       <th>NDCG@10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>HighestRatedRecommender</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.003333</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.001111</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Task 5.** Implement the RandomRecommender (check the slides for class 1), evaluate it with leave-one-out procedure for implicit feedback, print HR@1, HR@3, HR@5, HR@10, NDCG@1, NDCG@3, NDCG@5, NDCG@10.

# %%
class RandomRecommender(object):
    """
    Random recommender class.
    """
    
    def __init__(self):
        """
        Initialize base recommender params and variables.
        """
        self.shuffled = []
        self.rng = np.random.RandomState(seed=6789)
        pass
    
    def fit(self, interactions_df, users_df, items_df):
        """
        Training of the recommender.
        
        :param pd.DataFrame interactions_df: DataFrame with recorded interactions between users and items 
            defined by user_id, item_id and features of the interaction.
        :param pd.DataFrame users_df: DataFrame with users and their features defined by user_id and the user feature columns.
        :param pd.DataFrame items_df: DataFrame with items and their features defined by item_id and the item feature columns.
        """
        shuffle = np.arange(len(items_df))
        self.rng.shuffle(shuffle)
        shuffle = list(shuffle)
        
        self.shuffled = [items_df.iloc[x]['item_id'] for x in shuffle]
    
    def recommend(self, users_df, items_df, n_recommendations=1):
        """
        Serving of recommendations. Scores items in items_df for each user in users_df and returns 
        top n_recommendations for each user.
        
        :param pd.DataFrame users_df: DataFrame with users and their features for which recommendations should be generated.
        :param pd.DataFrame items_df: DataFrame with items and their features which should be scored.
        :param int n_recommendations: Number of recommendations to be returned for each user.
        :return: DataFrame with user_id, item_id and score as columns returning n_recommendations top recommendations 
            for each user.
        :rtype: pd.DataFrame
        """
        
        recommendations = pd.DataFrame(columns=['user_id', 'item_id', 'score'])
        
        for ix, user in users_df.iterrows():
            user_recommendations = pd.DataFrame({'user_id': user['user_id'],
                                                 'item_id': self.shuffled[:n_recommendations],
                                                 'score': [3.0] * n_recommendations})

            recommendations = pd.concat([recommendations, user_recommendations])

        return recommendations

recommender = RandomRecommender()
recommender.fit(ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], None, ml_movies_df)
results = [['RandomRecommender'] + list(evaluate_leave_one_out_implicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], ml_movies_df, max_evals=300, seed=6789))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])

display(HTML(results.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Recommender</th>
#       <th>HR@1</th>
#       <th>HR@3</th>
#       <th>HR@5</th>
#       <th>HR@10</th>
#       <th>NDCG@1</th>
#       <th>NDCG@3</th>
#       <th>NDCG@5</th>
#       <th>NDCG@10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>RandomRecommender</td>
#       <td>0.0</td>
#       <td>0.003333</td>
#       <td>0.006667</td>
#       <td>0.006667</td>
#       <td>0.0</td>
#       <td>0.001667</td>
#       <td>0.003102</td>
#       <td>0.003102</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Task 6.** Gather the results for TFIDFRecommender, MostPopularRecommender, HighestRatedRecommender, RandomRecommender in one DataFrame and print it.

# %%
tfidf_recommender = TFIDFRecommender()
tf_results = [['TFIDFRecommender'] + list(evaluate_leave_one_out_implicit(
    tfidf_recommender, ml_ratings_df.loc[:, ['user_id', 'item_id']], ml_movies_df, max_evals=300, seed=6789))]

tf_results = pd.DataFrame(tf_results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])


recommender = MostPopularRecommender()
mp_results = [['MostPopularRecommender'] + list(evaluate_leave_one_out_implicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id']], ml_movies_df, max_evals=300, seed=6789))]

mp_results = pd.DataFrame(mp_results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])


recommender = HighestRatedRecommender()
hr_results = [['HighestRatedRecommender'] + list(evaluate_leave_one_out_implicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], ml_movies_df, max_evals=300, seed=6789))]

hr_results = pd.DataFrame(hr_results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])


recommender = RandomRecommender()
r_results = [['RandomRecommender'] + list(evaluate_leave_one_out_implicit(
    recommender, ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], ml_movies_df, max_evals=300, seed=6789))]

r_results = pd.DataFrame(r_results, 
                       columns=['Recommender', 'HR@1', 'HR@3', 'HR@5', 'HR@10', 'NDCG@1', 'NDCG@3', 'NDCG@5', 'NDCG@10'])


result = pd.concat([tf_results, mp_results, hr_results, r_results])
result
# Out:
# <ipython-input-53-26e70434283d> in fit(self, interactions_df, users_df, items_df)
#      25         shuffle = list(shuffle)
#      26
# ---> 27         self.shuffled = [items_df.iloc[x]['item_id'] for x in shuffle]
#      28         print(self.shuffled)
#      29
#
# <ipython-input-53-26e70434283d> in <listcomp>(.0)
#      25         shuffle = list(shuffle)
#      26
# ---> 27         self.shuffled = [items_df.iloc[x]['item_id'] for x in shuffle]
#      28         print(self.shuffled)
#      29
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1496             self._validate_integer(key, axis)
#    1497
# -> 1498             return self.obj._ixs(key, axis=axis)
#    1499
#    1500     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    2831             # if we are a copy, mark as such
#    2832             copy = isinstance(new_values, np.ndarray) and new_values.base is None
# -> 2833             result = self._constructor_sliced(
#    2834                 new_values,
#    2835                 index=self.columns,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     325                     data = data.copy()
#     326             else:
# --> 327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
#     329                 data = SingleBlockManager.from_array(data, index)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     510                 subarr = np.array(data, dtype=object, copy=copy)
#     511
# --> 512         if is_object_dtype(subarr.dtype) and not is_object_dtype(dtype):
#     513             inferred = lib.infer_dtype(subarr, skipna=False)
#     514             if inferred in {"interval", "period"}:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_object_dtype(arr_or_dtype)
#     219     False
#     220     """
# --> 221     return _is_dtype_type(arr_or_dtype, classes(np.object_))
#     222
#     223
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/common.py in classes(*klasses)
#     178 def classes(*klasses) -> Callable:
#     179     """ evaluate if the tipo is a subclass of the klasses """
# --> 180     return lambda tipo: issubclass(tipo, klasses)
#     181
#     182
#
# KeyboardInterrupt:

# %% [markdown]
# **Task 7\*.** Implement an SVRRecommender - one-hot encode genres and fit an SVR model to
#
# (genre_1, genre_2, ..., genre_N) -> rating
#
# Tune params of the SVR model to obtain as good results as you can.
#
# To do tuning properly (although in practive people are often happy with leave-one-out and do not bother with dividing the set into training, validation and test sets):
#     - divide the set into training, validation and test sets (randomly divide the dataset in proportions 60%-20%-20%),
#     - train the model with different sets of tunable parameters on the training set,
#     - choose the best tunable params based on results on the validation set,
#     - provide the final evaluation metrics on the test set for the best model obtained during tuning.
#
# Recommended method of tuning: use hyperopt. Install the package using the following command: `pip install hyperopt`
#
# Print the RMSE and MAE on the test set generated with numpy with seed 6789.

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import MultiLabelBinarizer

class SVRRecommender(object):
    
    def __init__(self):
        self.model = None
        self.mlb = None
    
    def fit(self, interactions_df, users_df, items_df): 
        print('in fit')
        interactions_df = pd.merge(interactions_df, items_df, on='item_id')
        interactions_df.loc[:, 'genres'] = interactions_df['genres'].str.replace("-", "_", regex=False)
        interactions_df.loc[:, 'genres'] = interactions_df['genres'].str.replace(" ", "_", regex=False)
        interactions_df.loc[:, 'genres'] = interactions_df['genres'].str.lower()
        interactions_df.loc[:, 'genres'] = interactions_df['genres'].str.split("|")
        
        self.mlb = MultiLabelBinarizer()
        interactions_df = interactions_df.join(
            pd.DataFrame(self.mlb.fit_transform(interactions_df.pop('genres')),
                         columns=self.mlb.classes_,
                         index=interactions_df.index))
        
        x = interactions_df.loc[:, self.mlb.classes_].values
        y = interactions_df['rating'].values
    
        self.model = SVR(kernel='rbf', C=1.0, epsilon=0.1, gamma='scale').fit(x, y)
        print('end fit')
    
    def recommend(self, users_df, items_df, n_recommendations=1):
        
        items_df = items_df.copy()
        items_df.loc[:, 'genres'] = items_df['genres'].str.replace("-", "_", regex=False)
        items_df.loc[:, 'genres'] = items_df['genres'].str.replace(" ", "_", regex=False)
        items_df.loc[:, 'genres'] = items_df['genres'].str.lower()
        items_df.loc[:, 'genres'] = items_df['genres'].str.split("|")
        
        items_df = items_df.join(
            pd.DataFrame(self.mlb.transform(items_df.pop('genres')),
                         columns=self.mlb.classes_,
                         index=items_df.index))
    
        recommendations = pd.DataFrame(columns=['user_id', 'item_id', 'score'])
        
        for ix, user in users_df.iterrows():
            score = self.model.predict(items_df.loc[:, self.mlb.classes_].values)[0]
                
            user_recommendations = pd.DataFrame({'user_id': [user['user_id']],
                                                 'item_id': items_df.iloc[0]['item_id'],
                                                 'score': score})

            recommendations = pd.concat([recommendations, user_recommendations])

        return recommendations

# %%
svr_recommender = SVRRecommender()

results = [['SVRRecommender'] + list(evaluate_train_test_split_explicit(
    svr_recommender, ml_ratings_df.loc[:, ['user_id', 'item_id', 'rating']], ml_movies_df, seed=6789))]

results = pd.DataFrame(results, 
                       columns=['Recommender', 'RMSE', 'MRE'])

display(HTML(results.to_html()))
